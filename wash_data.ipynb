# %% [markdown]
# ### ChatGPT Chunk

# %%
import openai

openai.api_key = ""

def ask_chatgpt(prompt):
    
    completion = openai.ChatCompletion.create(
      model="gpt-3.5-turbo",
      temperature=0,
      messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt},
        ]
    )

    return completion

# %%
import pandas as pd
from langchain.document_loaders import DataFrameLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

df = pd.read_csv('document/clean_content_4.csv')

loader = DataFrameLoader(df, page_content_column="content")
docs = loader.load()

CHUNK_SIZE = 1024
CHUNK_OVERLAP = 0

child_splitter = RecursiveCharacterTextSplitter(
    chunk_size=CHUNK_SIZE, chunk_overlap=CHUNK_OVERLAP, add_start_index=True
)

all_splits = child_splitter.split_documents(docs)
faq_split_1024 = all_splits[-226:]
nan_faq_split_1024 = all_splits[:-226]
print(f'len(all_splits): {len(all_splits)}, len(nan_faq_split_1024): {len(nan_faq_split_1024)}')
# Out:
# len(all_splits): 19091, len(nan_faq_split_1024): 18865

# %%
faq_split_1024 = all_splits[-226:]
len(faq_split_1024)
# Out:
# 226

# %%
from tqdm import tqdm
import time

gpt_dic = {'url': [], 'chunks': []}
# ans = []
for idx, doc in enumerate(tqdm(nan_faq_split_1024[10557:])):
    prompt = f'''Decompose the "Content" into clear and simple propositions, ensuring they are interpretable out of context.
    1. Split compound sentence into simple sentences. Maintain the original phrasing from the input whenever possible.
    2. Remove the irrelevant content. 
    3. For any named entity that is accompanied by additional descriptive information, separate this information into its own distinct proposition.
    4. Decontextualize the proposition by adding necessary modifier to nouns or entire sentences and replacing pronouns (e.g., "it", "he", "she", "they", "this", "that") with the full name of the entities they refer to.
    5. Present the results as a list of strings, formatted in JSON.
    Input:"English  Version 國立臺灣大學圖書資訊學系 Department and Graduate Institute of Library and Information Science, National Taiwan University  選單
                        主選單 學士班獎助學金 僅提供系上開設獎學金消息 圖資系專屬獎學金一覽表 2023.09更新 臺大文學院獎助學金 臺大獎助學金一覽表 臺大弱勢助學金 臺大生活學習獎助金 國立臺灣大學希望助學金 (請以關鍵字搜尋希望助學金) LIS, NTU © All rights reserved since 2014"
    Output:["國立臺灣大學圖書資訊學系 Department and Graduate Institute of Library and Information Science, National Taiwan University  選單", "圖書資訊學系學士班獎助學金", "僅提供圖書資訊學系系上開設獎學金消息", "圖資系專屬獎學金一覽表 2023.09更新", "臺大文學院獎助學金", "臺大獎助學金一覽表", "臺大弱勢助學金", "臺大生活學習獎助金", "國立臺灣大學希望助學金 (請以關鍵字搜尋希望助學金)" ]
    Input:"{doc.page_content}"
    Output:
    '''
    # print(prompt)
    try:
        response = ask_chatgpt(prompt)['choices'][0]['message']['content']
        # print(response)
        # ans.append(response)
        gpt_dic['url'].append(nan_faq_split_1024[10557:][idx].metadata['url'])
        gpt_dic['chunks'].append(response)
        gpt_dic_df = pd.DataFrame(gpt_dic)
        gpt_dic_df.to_csv('document/non_faq_ChatGPT_chunk.csv', index=False)
    except:
        time.sleep(10)
        response = ask_chatgpt(prompt)['choices'][0]['message']['content']
        # print(response)
        # ans.append(response)
        gpt_dic['url'].append(nan_faq_split_1024[10557:][idx].metadata['url'])
        gpt_dic['chunks'].append(response)
        gpt_dic_df = pd.DataFrame(gpt_dic)
        gpt_dic_df.to_csv('document/non_faq_ChatGPT_chunk.csv', index=False)

    # if idx>0:
    #     break
# Out:
# 100%|██████████| 8308/8308 [29:31:12<00:00, 12.79s/it]

# %% [markdown]
# ### CHATGPT Chunk TEST

# %%
import json

gpt_chunk_df = pd.read_csv('document/all_chatgpt_chunk.csv')
gpt_sep_chunk = {'url': [], 'chunk': []}
for doc in gpt_chunk_df.iterrows():
    # print(doc)
    try:
        chunks = json.loads(doc[1][1])
        url = doc[1][0]
        # print(url, chunks)
        for chunk in chunks:
            gpt_sep_chunk['url'].append(url)
            gpt_sep_chunk['chunk'].append(chunk)
    except:
        print(doc)

gpt_sep_chunk_df = pd.DataFrame(gpt_sep_chunk)
print(f'len(gpt_all_splits): {len(gpt_sep_chunk_df)} {gpt_sep_chunk_df[:1]}')
# Out:
# (13, url                               http://www.oc.ntu.edu.tw/
# chunks    ["臺大海洋研究所謝志豪教授與碩士畢業生楊箴芸，使用新穎的研究船上實驗設計，首次提出海洋野外...
# Name: 13, dtype: object)
# (24, url                               https://rsprc.ntu.edu.tw/
# chunks    ["臺大風險中心（以下簡稱本中心）由本年度（2023年）展開的【青年淨零力實踐平台】活動專案...
# Name: 24, dtype: object)
# (90, url                             https://liberal.ntu.edu.tw/
# chunks    ["臺大首頁", "本院首頁", "網站導覽", "關於本院", "本院簡介（含歷任院長）"...
# Name: 90, dtype: object)
# (98, url                                  http://ibs.ntu.edu.tw/
# chunks    ["ç”\x9fç\x89©ã\x80\x81é\x86«å\xad¸ã\x80\x81å\...
# Name: 98, dtype: object)
# (123, url       https://www.ieee-pels.org/awards/pels/achievem...
# chunks    ["Join IEEE Sign In IEEE Power Electronics Soc...
# Name: 123, dtype: object)
# (165, url                        http://www.oc.ntu.edu.tw/?cat=30
# chunks    ["國立臺灣大學海洋研究所 大型研究計畫", "本所引進水下滑翔觀測載具Seaglider提...
# Name: 165, dtype: object)
# (193, url       https://www.nature.com/articles/s41586-021-034...
# chunks    ["contacts at room temperature", "they increas...
# Name: 193, dtype: object)
# (201, url       https://www.nature.com/articles/s41586-021-034...
# chunks    ["first-principles calculations", "tested in a...
# Name: 201, dtype: object)
# (639, url                            http://www.iwls.org/iwls2019
# chunks    ["Lunch at Auberge du Vigneron 14:00 - 15:00",...
# Name: 639, dtype: object)
# (772, url       https://www.econ.sinica.edu.tw/1/archives/daad...
# chunks    ["Financial System,” the Proceeding of Worksho...
# Name: 772, dtype: object)
# (964, url       http://www.bioagri.ntu.edu.tw/newsdetail.php?s...
# chunks    ["Yun Xiang Pork" brand, "strategic alliance c...
# Name: 964, dtype: object)
# (966, url       http://www.bioagri.ntu.edu.tw/newsdetail.php?s...
# chunks    ["Native pork must provide consumers with peac...
# Name: 966, dtype: object)
# (967, url       http://www.bioagri.ntu.edu.tw/newsdetail.php?s...
# chunks    ["The "Yun Xiang Pork" brand emphasizes five k...
# Name: 967, dtype: object)
# (1047, url       http://www.bioagri.ntu.edu.tw/newsdetail.php?s...
# chunks    ["The USR Program has been ongoing for many ye...
# Name: 1047, dtype: object)
# (1048, url       http://www.bioagri.ntu.edu.tw/newsdetail.php?s...
# chunks    ["integral part of Yunlin County", "academic r...
# Name: 1048, dtype: object)
# (1379, url        http://ntumisrc.blogspot.com/feeds/posts/default
# chunks    ["mso-hansi-font-family: &quot;Times New Roman...
# Name: 1379, dtype: object)
# (1386, url        http://ntumisrc.blogspot.com/feeds/posts/default
# chunks    ["href=\"https://1.bp.blogspot.com/-TssEYnUTA4...
# Name: 1386, dtype: object)
# (1401, url        http://ntumisrc.blogspot.com/feeds/posts/default
# chunks    ["13.5pt", ")", "<o:p></o:p>", "</span></span>...
# Name: 1401, dtype: object)
# (1414, url        http://ntumisrc.blogspot.com/feeds/posts/default
# chunks    ["lang="EN-US"><o:p></o:p></span></p><p class=...
# Name: 1414, dtype: object)
# (1428, url        http://ntumisrc.blogspot.com/feeds/posts/default
# chunks    ["and Interface Div., Chemical Soc. Jpn</a>.<o...
# Name: 1428, dtype: object)
# (1554, url                   http://www.oc.ntu.edu.tw/?page_id=131
# chunks    ["７２學年：丁必誠", "吳繼倫", "陳志遠", "張文炳", "邱建勇", "郭立信"...
# Name: 1554, dtype: object)
# (1556, url                   http://www.oc.ntu.edu.tw/?page_id=131
# chunks    ["９１學年：林筱齡", "９１學年：陳昭強", "９１學年：蔡育奇", "９１學年：蕭仁宏...
# Name: 1556, dtype: object)
# (1557, url                   http://www.oc.ntu.edu.tw/?page_id=131
# chunks    ["９７學年：高慧如", "蔡季達", "李信宏", "鄭智睿", "陳冠樵", "潘昌志"...
# Name: 1557, dtype: object)
# (1581, url       http://ntumisrc.blogspot.com/search/label/4.%E...
# chunks    ["最新消息 2016年8月14日 星期日 [徵才] 國立台灣大學化學工程學系廖英志教授-徵...
# Name: 1581, dtype: object)
# (1739, url                       http://140.112.63.111/geogflower/
# chunks    ["真的該如此嗎？", "廟方捍衛青山王祭的目的在於延續這個「共同回憶」", "廟方捍衛青山...
# Name: 1739, dtype: object)
# (1777, url                       http://140.112.63.111/geogflower/
# chunks    ["這位學生的表現", "彥甫學長打開了知名度"]\n["他當時仍心心念念學術研究", "這...
# Name: 1777, dtype: object)
# (1795, url                       http://140.112.63.111/geogflower/
# chunks    ["鄒志揚", "邱雲茗", "鄒志揚", "環境科學", "翁葳老師", "環境科學", ...
# Name: 1795, dtype: object)
# (1798, url                       http://140.112.63.111/geogflower/
# chunks    ["生態學的研究取徑包含生物族群為主的族群典範", "生態學的研究取徑包含生態系統為主的生態...
# Name: 1798, dtype: object)
# (1810, url                       http://140.112.63.111/geogflower/
# chunks    ["Conversation。取自：http://theconversation.com/w...
# Name: 1810, dtype: object)
# (2195, url                          http://sdg.bioagri.ntu.edu.tw/
# chunks    ["Dr Nai-Chieh Liu has recently become one of ...
# Name: 2195, dtype: object)
# (2275, url                          http://sdg.bioagri.ntu.edu.tw/
# chunks    ["本獎學金審核結果與相關訊息一律以本校學生「學號信箱」作為聯繫通知管道，請自行留意電子信箱...
# Name: 2275, dtype: object)
# (2306, url                          http://sdg.bioagri.ntu.edu.tw/
# chunks    ["also fit in one of the following categories:...
# Name: 2306, dtype: object)
# (2325, url                          http://sdg.bioagri.ntu.edu.tw/
# chunks    ["Dr. Kuo Rei-Lin delivered a lecture on his s...
# Name: 2325, dtype: object)
# (2419, url                           http://po.oc.ntu.edu.tw/buoy/
# chunks    ["海上浮標護衛臺灣，讓準確預報颱風不是夢", "全球首例！台大「捕風」揭限制颱風成長之謎／...
# Name: 2419, dtype: object)
# (2754, url                       http://www.oc.ntu.edu.tw/?p=20669
# chunks    ["國立臺灣大學海洋研究所 《臺灣區域海洋學》獲科技部最佳「研值」好書群聚 Posts Ga...
# Name: 2754, dtype: object)
# (2810, url       http://ntumisrc.blogspot.com/search/label/6.%E...
# chunks    ["Collaboration Project Result T. Ohmura and T...
# Name: 2810, dtype: object)
# (3161, url       https://www.coursera.org/learn/chinese-garden-...
# chunks    ["University We firmly believe that open acces...
# Name: 3161, dtype: object)
# (3232, url       https://www.ntu.edu.tw/./spotlight/spotlight.html
# chunks    ["幽門螺旋桿菌為胃癌的主要原因", "臺大醫院長期針對胃癌高風險民眾，提供幽門螺旋桿菌篩檢...
# Name: 3232, dtype: object)
# (3240, url       https://www.ntu.edu.tw/./spotlight/spotlight.html
# chunks    ["臺大地質系博士後研究員胡訓銘", "中央研究院環境變遷研究中心副研究員李時雨", "地質...
# Name: 3240, dtype: object)
# (3303, url                    https://ntubeats.ntu.edu.tw/enews/83
# chunks    ["flexibility in presenting teaching materials...
# Name: 3303, dtype: object)
# (3537, url       https://www.coursera.org/learn/chinese-garden-...
# chunks    ["University We firmly believe that open acces...
# Name: 3537, dtype: object)
# (3794, url             https://ntubeats.ntu.edu.tw/enews/91/00.pdf
# chunks    ["NTU’s long-term support and the efforts made...
# Name: 3794, dtype: object)
# (3880, url         https://ntubeats.ntu.edu.tw/pdf/044fulltext.pdf
# chunks    ["behind business etiquette.", "Computer Progr...
# Name: 3880, dtype: object)
# (4025, url          https://oiainternship.ntu.edu.tw/news/view/236
# chunks    ["About This Program NTU & OIA Global Talent A...
# Name: 4025, dtype: object)
# (4141, url         https://ntubeats.ntu.edu.tw/pdf/028fulltext.pdf
# chunks    ["TAFP will play an important role in ensuring...
# Name: 4141, dtype: object)
# (4427, url                 https://ord.ntu.edu.tw/w/ordntuEN/Index
# chunks    ["Project Application", "Personnel Management"...
# Name: 4427, dtype: object)
# (4477, url         https://ntubeats.ntu.edu.tw/pdf/002fulltext.pdf
# chunks    ["teaching centers can play a powerful role in...
# Name: 4477, dtype: object)
# (4482, url         https://ntubeats.ntu.edu.tw/pdf/002fulltext.pdf
# chunks    ["lecture series", "Dr. Yip's series of lectur...
# Name: 4482, dtype: object)
# (4485, url         https://ntubeats.ntu.edu.tw/pdf/002fulltext.pdf
# chunks    ["find information about also actively seeking...
# Name: 4485, dtype: object)
# (4701, url            https://ntubeats.ntu.edu.tw/enews/004/00.pdf
# chunks    ["+886-2-3366-2577", "No.1, Sec. 4, Roosevelt ...
# Name: 4701, dtype: object)
# (4812, url         https://ntubeats.ntu.edu.tw/pdf/031fulltext.pdf
# chunks    ["Research in 2011", "the second paper, “Tempo...
# Name: 4812, dtype: object)
# (4924, url                    https://ntubeats.ntu.edu.tw/enews/66
# chunks    ["Themed“ Back in Time,” the opening ceremony ...
# Name: 4924, dtype: object)
# (4970, url                    https://ntubeats.ntu.edu.tw/enews/66
# chunks    ["NTU at a Glance Group photo for College of M...
# Name: 4970, dtype: object)
# (4971, url                    https://ntubeats.ntu.edu.tw/enews/66
# chunks    ["The Maple Chamber Ensemble, formed by physic...
# Name: 4971, dtype: object)
# (5044, url       https://sustainable.ntu.edu.tw/uploads/files/s...
# chunks    ["試驗等方式，把關和改善豬隻的健康。", "未來包括家禽、草食與水產動物的飼養管理，臺大團...
# Name: 5044, dtype: object)
# (5064, url       https://sustainable.ntu.edu.tw/uploads/files/s...
# chunks    ["臺大為表揚學生關懷社會、發揮利他精神並鼓勵學生貢獻社會，設置「學生社會奉獻特別獎」，除頒...
# Name: 5064, dtype: object)
# (5070, url       https://sustainable.ntu.edu.tw/uploads/files/s...
# chunks    ["餐飲減碳課程", "指導愛惜食物", "避免食物浪費", "使用在地食材", "縮短運送...
# Name: 5070, dtype: object)
# (5096, url       https://visitorcenter.ntu.edu.tw/eng/cl_n_1697...
# chunks    ["Skip to main content", "VisitorCenterEn Virt...
# Name: 5096, dtype: object)
# (5122, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["組織與職掌 學務處目前編制有學生事務長 1 名，副學務長 1 名、秘書 2 名，下設「生...
# Name: 5122, dtype: object)
# (5156, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["張嘉倩　德州大學奧斯汀校區外語教育研究所博士", "黃宗慧 國立台灣大學外文所博士", ...
# Name: 5156, dtype: object)
# (5197, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["數學教室", "臺大數學系", "本系與中研院數學研究所合建天文數學大樓", "數學系接...
# Name: 5197, dtype: object)
# (5279, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["邱瀚模　台北醫學院醫學士", "施金元　台灣大學臨床醫學研究所博士", "蘇大成 台大公...
# Name: 5279, dtype: object)
# (5280, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["姜文智", "台北醫學院醫學士", "楊紹佑", "台大醫學院醫學系醫學士", "張恬君...
# Name: 5280, dtype: object)
# (5281, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["陳美秀", "台大醫學院醫學系醫學士", "戴東原", "日本新瀉大學醫學博士", "徐...
# Name: 5281, dtype: object)
# (5285, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["黃勝堅　台灣大學醫學院醫學系學士", "黃約翰　台灣大學醫學院臨床醫學研究所博士", "...
# Name: 5285, dtype: object)
# (5287, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["年升格為泌 凍治療及機械人手臂輔助手術之訓練中心", "尿部，本部於 2015 年 8 ...
# Name: 5287, dtype: object)
# (5289, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["教授擔任。", "臺北帝國大學醫學部於 1936 年成立", "臺北醫院改制為臺北帝國大...
# Name: 5289, dtype: object)
# (5299, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["星期之必修課程，除設有教學門診，另對醫學生之 胡芳蓉　臺大醫學院醫學士 教學製作錄影帶輔...
# Name: 5299, dtype: object)
# (5300, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["教學研究設備", "具備眼科學檢查的基本技能", "具備眼科學檢查的基本技能", "具備...
# Name: 5300, dtype: object)
# (5310, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["教學研究設備", "名譽教授 郭宗禮", "日本岡山大學醫學部法醫毒物學博士", "本科...
# Name: 5310, dtype: object)
# (5315, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["博士生 兼任教師：7 人", "吳爵宏 臺大醫學院醫學系學士", "博士學位：7 人",...
# Name: 5315, dtype: object)
# (5319, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["人（含合聘教師 1 人）", "基礎領域的皮膚生理學", "基礎領域的皮膚病理學", "...
# Name: 5319, dtype: object)
# (5320, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["掃描機", "熱昇華印相機", "六頭光學顯微鏡", "投射資訊交流式光學顯微鏡", "...
# Name: 5320, dtype: object)
# (5378, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["教授 電腦模擬 楊家榮 Chia-Ron Yang", "副教授 藥理學 十八｜ 癌症研...
# Name: 5378, dtype: object)
# (5388, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["本院成立初期所設置之電機工程學系所及後續程學研究所、醫學工程學研究所、高分子科學與工增設...
# Name: 5388, dtype: object)
# (5393, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["2014 年之 QS 導原則下，本系悠久的歷史已培養出許多國內機械 世界排名躍升至第 3...
# Name: 5393, dtype: object)
# (5394, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["賴君亮　美國凱斯西儲大學博士", "潘國隆　美國普林斯頓大學博士", "吳文方　美國伊利...
# Name: 5394, dtype: object)
# (5442, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["轉殖技術", "農藥化學", "分子微生物", "環境微生物", "工業微生物", "食...
# Name: 5442, dtype: object)
# (5476, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["本系以教育及培訓不同動物種別之專業獸醫師", "專任教師包括：與獸醫相關科技之教學及研究...
# Name: 5476, dtype: object)
# (5516, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["網路技術與應用", "資料庫管理", "系統分析與設計", "管理學設計", "網路規劃...
# Name: 5516, dtype: object)
# (5519, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["整擴大學系的師資，進一步打造新時代的公共衛生 是臺灣首創的公共衛生學系。",\n"公共衛...
# Name: 5519, dtype: object)
# (5527, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["博士班畢業最低學分數：18 學分", "圖書及儀器設備 （不包含論文）", "本所相關圖...
# Name: 5527, dtype: object)
# (5537, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["資訊相關系所既有之卓越辦學績效", "擔負起培育研究中心之任務", "擔負起提昇國家競爭...
# Name: 5537, dtype: object)
# (5550, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["題研究、專題演講、論文及大學部課程", "應修習「本所光電相關科目」與「本所認定科目」合...
# Name: 5550, dtype: object)
# (5686, url                                 https://atgs.ntu.edu.tw
# chunks    ["Professor Wen-Ju Yang (楊雯如)", "Professor Pin...
# Name: 5686, dtype: object)
# (5701, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["Shes Tele evi", "SEMAN Beach", "aS", "SEPA E...
# Name: 5701, dtype: object)
# (5702, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["a PC A HTH ° PAT B SCE", "HRI TEDS R SRA SC ...
# Name: 5702, dtype: object)
# (5703, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["world 1 | WA\N a ypeioh PP es Re (SREP ARR e...
# Name: 5703, dtype: object)
# (5704, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["12 A> Axe BL PE tia ° TN IN NEE SE a A FREY ...
# Name: 5704, dtype: object)
# (5707, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["EA EEL FE A Bebe > DA 38h BASS Hy Zs Kis E s...
# Name: 5707, dtype: object)
# (5712, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["Kansas PRA L BBaAB MR Bae PEXABMAR PRA L AIG...
# Name: 5712, dtype: object)
# (5717, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["ily > BETH TS BR Bd 97 EBB Se oS — BAe BET A...
# Name: 5717, dtype: object)
# (5721, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["Bape ZS 32: PURBAS AMR - 33 PUL ENEMY > UR D...
# Name: 5721, dtype: object)
# (5728, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["EPRI Ae BE AE RL EIS BT RSS SEAS CAPE > REZ ...
# Name: 5728, dtype: object)
# (5729, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["HS TE Fo (RAEEA RPE > ACDAPAMHINSEEER + Ba i...
# Name: 5729, dtype: object)
# (5735, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["WBBR - (BK BPO - GBR. BK Fi BSRASAWUBESARASR...
# Name: 5735, dtype: object)
# (5737, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["BSC ABR © Lk AS BEEBE (199702 200207 } SCPCA...
# Name: 5737, dtype: object)
# (5738, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["BSRASAWUBESARASR> SB GT AE A IMMUN ULL HEABR...
# Name: 5738, dtype: object)
# (5740, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["200207 } SCPCARTAL UE ° 2004 EME ER Et thAa ...
# Name: 5740, dtype: object)
# (5742, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["Beat BA PRATRERL AH 10 Ke SRE MSSSWHALEM BUN...
# Name: 5742, dtype: object)
# (5744, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["ZARETRAMAR Bi Br 51 SHAM FRESE FRBR BRR BSE ...
# Name: 5744, dtype: object)
# (5746, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["BOAT ATE SES Ro 1962 F HRAZEBAARMARAE HERA \...
# Name: 5746, dtype: object)
# (5747, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["t rieces release the cells Drilling a hole f...
# Name: 5747, dtype: object)
# (5748, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["MHRA BRAM", "MH FERROUS", "BRIM BAR", "REE P...
# Name: 5748, dtype: object)
# (5752, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["ERR (1996.08 - 1999.07 } AAS ABH RZ Helis ° ...
# Name: 5752, dtype: object)
# (5754, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["SEZREBAANZR te SREB BLIR A SARA EL A alll © ...
# Name: 5754, dtype: object)
# (5757, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["SMRo—FWHWOM: DAR=A RAM RERKBSSA— STI EERR{L ...
# Name: 5757, dtype: object)
# (5759, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["MSA, RMS As: BAK BtAR S(cBAR> RE 50R ABR AWE...
# Name: 5759, dtype: object)
# (5760, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["SHAE WO TAH SSO > RARE EHIEN SHH BE aR SHE |...
# Name: 5760, dtype: object)
# (5762, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["BB Rik S BI BARGE AR FE NL", "BARB", "A MTS ...
# Name: 5762, dtype: object)
# (5763, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["BAR FRR 1 AVAWIR ° Batt ASBA U. BWA ee ZES R...
# Name: 5763, dtype: object)
# (5764, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["Hif> af) s JA ° 2006 SF eRAA MCE 1H ° His 4?...
# Name: 5764, dtype: object)
# (5765, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["LAARPOSAMMARE ARAMA BRERA ny FAS FB oy 5 EB ...
# Name: 5765, dtype: object)
# (5767, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["RAB 4+ MPT RS BOSSA (oe AD BT Rat . PTE LEE ...
# Name: 5767, dtype: object)
# (5769, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["http://www.psc.ntu.edu.tw", "http://gender.p...
# Name: 5769, dtype: object)
# (5771, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["EMA A RAERAL Re (EXGHARA RISC ie © 5: SURE I...
# Name: 5771, dtype: object)
# (5772, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["81 Ba SRSA PER AO ABD HEMI AIAN TR Ri ADRENA...
# Name: 5772, dtype: object)
# (5778, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["BBR ARIAT ZATRE MB HA ZARRMB 3 SMM A AR ARAM...
# Name: 5778, dtype: object)
# (5780, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["PRIETT ADT > AB + ARIA ES I Sag : HR © ON DA...
# Name: 5780, dtype: object)
# (5781, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["APA PEBRAIBE + GEMM s ARR GIE HERR BUA ° Ito...
# Name: 5781, dtype: object)
# (5783, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["s OF AUSAR » BEAT AA 4 A DLR LEER are: EBRAM...
# Name: 5783, dtype: object)
# (5793, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["Bit SAGAR Bie) BZ HTS RR —). MBH : ABPRAN : ...
# Name: 5793, dtype: object)
# (5794, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["LL EBA RK RWW AMR ARHKBEE BkARNRAWEA : Bake ...
# Name: 5794, dtype: object)
# (5797, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["LUEAAKZCHRRSHABAN > RARE S B+ AIMS RMEMBBE ©...
# Name: 5797, dtype: object)
# (5799, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["ARB SAR HERO REMERS 1b MIKA: Dh BRB ROHFAE >...
# Name: 5799, dtype: object)
# (5802, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["Malait SV 55: 3 a = ] =ediasie el SR = i 200...
# Name: 5802, dtype: object)
# (5808, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["LIAR EE + ftp » BBS » #888 im t@ s HESEMSER ...
# Name: 5808, dtype: object)
# (5810, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["CLUE CU UCU UU ERRGEIRIS + SIGH ZAMS SMBS - ...
# Name: 5810, dtype: object)
# (5816, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["RTMIS 7c ° RL > Bt EK IR © 1994 FEY BITE) SC...
# Name: 5816, dtype: object)
# (5824, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["VE A Gt AaE * APE 02) BOS) DIE 88) BF 20) = ...
# Name: 5824, dtype: object)
# (5837, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["ZS fh TW ERA AA ZR > BRMAHULZ ER LAUER Set L...
# Name: 5837, dtype: object)
# (5840, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["BRIAR sh PR A Ta CS TI et Sho SHER RET 2. RE...
# Name: 5840, dtype: object)
# (5845, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["Sifehit SSRI SAR ASKS PIE = EBUIS e e BONE e...
# Name: 5845, dtype: object)
# (5855, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["we PBF $s ON TEA BL HEMEL RIALS WEE A — aise...
# Name: 5855, dtype: object)
# (5858, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["L(2)", "ME YALRE IAB)", "KSA ITAA (3)", "tat...
# Name: 5858, dtype: object)
# (5877, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["1k BR FBR INIA AR Se aM SRB: BURR PT ES BIBS...
# Name: 5877, dtype: object)
# (5888, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["ntupath/ bt http://www.mc.ntu.edu.tw/departm...
# Name: 5888, dtype: object)
# (5892, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["ALLL FRA Z TZ Be ell 3 3 RPA SE RAZ MNS!", "...
# Name: 5892, dtype: object)
# (5900, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["department.asp EB. BSR £2. BER SLES ALHE ° I...
# Name: 5900, dtype: object)
# (5906, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["5S Tr i BA PASI RE/ | eB > BES) EAU > F3/)\5...
# Name: 5906, dtype: object)
# (5908, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["RA PAR AE BE NT at Bt EAE oD FT ER) A RES SE...
# Name: 5908, dtype: object)
# (5921, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["Bi a if > Br ERE Bi atin @& > FEA AE teat ai...
# Name: 5921, dtype: object)
# (5926, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["TEA Hest STEREOS BCE HEN ZT RIL © MBL al HEE...
# Name: 5926, dtype: object)
# (5935, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["ELE Be SARs SS TCT PRE SERRA + AT ENS AS Bl ...
# Name: 5935, dtype: object)
# (5949, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["Pho» PRE > PRATIBE > SEAR > BLEUE + WEE » “T...
# Name: 5949, dtype: object)
# (5962, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["AT REM FA > RETR PBR UE AA ~ ERA BARD > JBL ...
# Name: 5962, dtype: object)
# (5976, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["TRY CU A BOKER CEN Ebe A> AUS CURED OF oe 2....
# Name: 5976, dtype: object)
# (5990, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["BOLERO BUY» BT ASER > TBE ERAS?", "SECRET FE...
# Name: 5990, dtype: object)
# (5997, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["AEP RE VE °c AE RSENGE EAS Zee ial", "WFC HE...
# Name: 5997, dtype: object)
# (6028, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["ze BE Vy Sa ARLL > HSH TNE > ie GRETA TAD > ...
# Name: 6028, dtype: object)
# (6032, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["ExecuCOMP » JSTORE", "im tat Co ON DH F&F KW...
# Name: 6032, dtype: object)
# (6049, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["USERS SEGRE eB: BNE BAS Se EL: BN SKS Se BRM...
# Name: 6049, dtype: object)
# (6051, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["susniyscetaemenmtng + ah cacsneweate PESESEM...
# Name: 6051, dtype: object)
# (6061, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["RELEASE WR < ALMA < RMAC eR SO Bale HbA PDE ...
# Name: 6061, dtype: object)
# (6065, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["PREECE AE + CAE + ee ihe Ball mt oe rz Yr SK...
# Name: 6065, dtype: object)
# (6070, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["F EEE Ta if FRGLET ASAE > WEA ARS ELI > PRUE...
# Name: 6070, dtype: object)
# (6075, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["IAI E ° BHHACRL ANH Ce Sa EBS EE PRES a > (E...
# Name: 6075, dtype: object)
# (6144, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["東亞文化（東南亞為印度與伊斯蘭文明的影響範圍， 外王、天人合一，流弊則可能淪為保守封閉。...
# Name: 6144, dtype: object)
# (6150, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["年\t 1 月，90 學年度第 1 學期第 2 次校務會議 通過本校與中央研究院合作辦理...
# Name: 6150, dtype: object)
# (6151, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["合約，打造世界一流的癌症醫院。", "SOC 論 文 在 2009 年 IEEE\tIS...
# Name: 6151, dtype: object)
# (6165, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["國立臺灣大學 Proteminer、MEDOCK、Prote2S、EIDS、DBDBS ...
# Name: 6165, dtype: object)
# (6181, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["最後一批以專機由大陸搶接先來台之學界耆", "社會培育高級外國語文及學術人才", "朱立...
# Name: 6181, dtype: object)
# (6209, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["本所位於「樂學館」一樓（舊總圖後棟一 樓）",\n "目前擁有隔音教室2間，分別作為多媒...
# Name: 6209, dtype: object)
# (6227, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["視為國內最高層級之物理科學教學與研究機構， 對國內物理科學的茁壯成熟，深感責無旁貸，並 ...
# Name: 6227, dtype: object)
# (6231, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["博士學位：55人", "碩士學位：1人", "教授兼系主任 楊吉水　美國西北大學博士",...
# Name: 6231, dtype: object)
# (6236, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["質譜儀", "穩定同位素質譜儀", "稀有氣體分析質譜儀", "沉積實驗室", "熱螢光...
# Name: 6236, dtype: object)
# (6389, url         https://ntubeats.ntu.edu.tw/pdf/020fulltext.pdf
# chunks    ["individual qualities, as well as expand and ...
# Name: 6389, dtype: object)
# (6443, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["專任教師︰28人", "兼任教師︰31人", "博士學位︰55人", "碩士學位︰4人"...
# Name: 6443, dtype: object)
# (6446, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["教授兼系主任 苑舉正　比利時魯汶大學哲學博士", "專任教師 教授 傅佩榮　美國耶魯大學...
# Name: 6446, dtype: object)
# (6733, url                 https://ntubeats.ntu.edu.tw/pdf/068.pdf
# chunks    ["Prof. Hui-Chen Lin of “Surf & Turf” presente...
# Name: 6733, dtype: object)
# (7003, url       https://my.ntu.edu.tw/assistant/doc/forum10601...
# chunks    ["BA Ew ah BE: 10617 3b EM BAP HE Ut Be At Bas...
# Name: 7003, dtype: object)
# (7004, url       https://my.ntu.edu.tw/assistant/doc/forum10601...
# chunks    ["國立臺灣大學圖書資訊學系 Department and Graduate Institu...
# Name: 7004, dtype: object)
# (7156, url             https://ntubeats.ntu.edu.tw/enews/94/00.pdf
# chunks    ["onsite welcome party at the start of the sem...
# Name: 7156, dtype: object)
# (7159, url             https://ntubeats.ntu.edu.tw/enews/94/00.pdf
# chunks    ["and assume the role of transforming, changin...
# Name: 7159, dtype: object)
# (7282, url                    https://ntubeats.ntu.edu.tw/enews/70
# chunks    ["isolated epididymosome", "QSOX2 is regulated...
# Name: 7282, dtype: object)
# (7351, url         https://ntubeats.ntu.edu.tw/pdf/050fulltext.pdf
# chunks    ["National Taiwan University", "Website:http:/...
# Name: 7351, dtype: object)
# (7436, url                 https://ntubeats.ntu.edu.tw/pdf/088.pdf
# chunks    ["international assistance are of great signif...
# Name: 7436, dtype: object)
# (7498, url                 https://ntubeats.ntu.edu.tw/pdf/088.pdf
# chunks    ["newly established preparatory committee for ...
# Name: 7498, dtype: object)
# (7536, url                              https://www.paih.gov.pl/en
# chunks    ["Krucza St. 50 00-025 Warsaw", "Contact PAIH2...
# Name: 7536, dtype: object)
# (7568, url         https://ntubeats.ntu.edu.tw/pdf/015fulltext.pdf
# chunks    ["Attendees learned of India’s long cultural h...
# Name: 7568, dtype: object)
# (7716, url             https://ntubeats.ntu.edu.tw/enews/93/00.pdf
# chunks    ["recognition of their outstanding contributio...
# Name: 7716, dtype: object)
# (7744, url                    https://ntubeats.ntu.edu.tw/enews/81
# chunks    ["Spike", "3CLpro", "PLpro", "RdRp", "N protei...
# Name: 7744, dtype: object)
# (7777, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["資訊網路中心", "六個學院，包含附設醫院、農場等，以及教務處、訓導處、總務處", "徐...
# Name: 7777, dtype: object)
# (7857, url         https://ntubeats.ntu.edu.tw/pdf/065fulltext.pdf
# chunks    ["popularize academic knowledge and, looking t...
# Name: 7857, dtype: object)
# (7899, url                 https://ntubeats.ntu.edu.tw/pdf/082.pdf
# chunks    ["Published by National Taiwan University Webs...
# Name: 7899, dtype: object)
# (7963, url                 https://ntubeats.ntu.edu.tw/pdf/082.pdf
# chunks    ["COVID-19", "started getting to know each oth...
# Name: 7963, dtype: object)
# (8269, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["國立臺灣大學醫學院", "醫科畢業", "日本國立東京大學博士", "曾任臺灣大學生",...
# Name: 8269, dtype: object)
# (8275, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["性侵犯防治委員會", "由校長遴聘本校教師、職工與學生代表組成"]\n["成立校園規劃小...
# Name: 8275, dtype: object)
# (8307, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["資訊網路組 作業管理組負責校級資訊系統及計算機系統之管", "負責規劃、建置、管理及維護...
# Name: 8307, dtype: object)
# (8391, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["專題討論（2）", "書報討論（2）", "地質海上實習（1）", "海洋化學組 專題討...
# Name: 8391, dtype: object)
# (8452, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["來應加強整合，特別是基因醫學各領域之相關研究， 並建構研究之核心技術平臺，引進博士及博士...
# Name: 8452, dtype: object)
# (8453, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["王治元 臺大生理研究所博士", "謝思民 臺北醫學院醫學士", "廖偉智 臺大醫學院醫學...
# Name: 8453, dtype: object)
# (8454, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["高雄醫學院醫學士 許嘉林", "中國醫藥學院醫學士 李宗錞", "臺北醫學院醫學士 黃惠...
# Name: 8454, dtype: object)
# (8455, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["臺灣大學臨床醫學研究所博士 吳志成", "陽明醫學院醫學士 許金川", "臺灣大學臨床醫...
# Name: 8455, dtype: object)
# (8458, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["臺灣大學醫學院臨床醫學研究所博士 兼任教授：7 人 袁瑞晃", \n"臺灣大學醫學院臨床...
# Name: 8458, dtype: object)
# (8462, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["許耕榕", "王炯珵", "蔡芳生", "蔣智宏", "兼任講師"]\n["謝德生", ...
# Name: 8462, dtype: object)
# (8464, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["臨床講師：9 人", "簡穎秀 臺大醫學院臨床醫學研究所博士", "兼任講師：13 人"...
# Name: 8464, dtype: object)
# (8474, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["博士學位：12 人", "碩士學位：14 人", "教授兼科主任 楊中美", "臺大醫學...
# Name: 8474, dtype: object)
# (8506, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["協助牙醫師與各類牙科輔助人員在職訓練，以全盤改善我國之牙科醫療現況。",\n"教導提供高...
# Name: 8506, dtype: object)
# (8571, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["程學、化學工程學、工程科學及海洋工程學、材料 科學與工程學等 5 個系所及環境工程學（1...
# Name: 8571, dtype: object)
# (8572, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["嚴慶齡工業研究中心", "水工試驗所", "地震工程研究中心", "製造自動化研究中心"...
# Name: 8572, dtype: object)
# (8643, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["賽、3 月的杜鵑花節、5 月的農經之夜、6 月的體育競賽週及 7 月的農村服務隊，透過這...
# Name: 8643, dtype: object)
# (8646, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["美國西北大學土木研究所博士 黃鵬林", "德國科隆大學生物化學博士 曹　正", "美國威...
# Name: 8646, dtype: object)
# (8664, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["張芳嘉 美國德州大學神經科學博士", "周崇熙 美國密西西比州立大學獸醫學博士 副教授"...
# Name: 8664, dtype: object)
# (8678, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["林安仲院長", "陳光陽院長", "劉朝鑫院長", "郭宗甫院長", "龐飛院長", "...
# Name: 8678, dtype: object)
# (8690, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["2011 年「Stochastic Programming Workshop」、 6 學...
# Name: 8690, dtype: object)
# (8732, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["健康行為與社區科學已經於 2015 年成立研究所，招收碩士班學生",\n"健康政策與管理...
# Name: 8732, dtype: object)
# (8736, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["博士學位：128 人", "碩士學位：1 人", "教授兼系主任 劉志文", "美國康乃...
# Name: 8736, dtype: object)
# (8737, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["國立交通大學光電博士 黃俊郎", "美國加州大學聖塔芭芭拉分校電機與電腦工 黃天偉", ...
# Name: 8737, dtype: object)
# (8769, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["強化論文發表機制", "鼓勵師生間以經常舉辦之學術討論會作為知識上及情感上之交流平臺",...
# Name: 8769, dtype: object)
# (8823, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["Sciences E9 E9 E8 S2 CZ13 M7 M8", "生物資源暨農學院 ...
# Name: 8823, dtype: object)
# (8895, url       https://www.nature.com/articles/s41467-023-428...
# chunks    ["dispersion relation of internal gravity wave...
# Name: 8895, dtype: object)
# (8896, url       https://www.nature.com/articles/s41467-023-428...
# chunks    ["is the angular velocity", "\(\bar{\xi }\) is...
# Name: 8896, dtype: object)
# (8942, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["Ue a BRU eb op Ue Et cea e8 Ee MN eh eee gee...
# Name: 8942, dtype: object)
# (8943, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["OAS SHS A PA REll MRS MBA AE DLE HL ARS BY E...
# Name: 8943, dtype: object)
# (8949, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["rs eee 8 ee eee ea & BY 3B (Teaching Assista...
# Name: 8949, dtype: object)
# (8951, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["BASKBSSRMRTAL: SAUMUR SSH Ral tas echstiel i...
# Name: 8951, dtype: object)
# (8952, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["ASS BE the BH SE aR BEREA+IE: AT BEIREHESTFB...
# Name: 8952, dtype: object)
# (8960, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["ARBAMREMERS EHS SHARE > EAESb SER Er eS n| 4...
# Name: 8960, dtype: object)
# (8961, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["1970 RBA ° BREGLSRH GHB RR", "BAAS RM + BR 1...
# Name: 8961, dtype: object)
# (8962, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["BE AS TSR SE Ly + ATT + HW LEAH + BOE EE + T...
# Name: 8962, dtype: object)
# (8969, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["BETAS Re BLS SE EI TENS is LAR SR OIME MAZ »...
# Name: 8969, dtype: object)
# (8972, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["YORE aT BSKAMAS SRR RB 92 pki", "PEAS RLARC ...
# Name: 8972, dtype: object)
# (8975, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["TREE s PAAR Bb LN BR RS 63 ‘y Eh 18 SBS} © B...
# Name: 8975, dtype: object)
# (8983, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["SUE a Beda fala Bee oe Ge Tay Rif RBS HEAD a...
# Name: 8983, dtype: object)
# (8985, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["MFT BO) KREROERAS SRNRALE > Al RRB BS Rete +...
# Name: 8985, dtype: object)
# (8989, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["Hk email RERBEB MESWSEAM: VEBARHTRRARHATH 7”...
# Name: 8989, dtype: object)
# (8992, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["PISCE SAB 20 BREE AS BIABABZ ie MAMA + MR AR...
# Name: 8992, dtype: object)
# (8993, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["A RAR ARSE 35)", "Hoe SSB A SR He LH 42 ET)"...
# Name: 8993, dtype: object)
# (8995, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["LURRA GHAR AK WR RE Service-Oriented Archite...
# Name: 8995, dtype: object)
# (9014, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["楊泮池先生就任第 11 任校長", "校長率領師生共75人參訪臺大校園", "成立藥學專...
# Name: 9014, dtype: object)
# (9034, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["暑假期間赴國外學校進行 3-6 週不等的短期進修機會", "今日臺大｜國際交流｜ 201...
# Name: 9034, dtype: object)
# (9060, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["人", "本系的課程", "本系的課程", "本系的課程", "本系的課程", "本系的...
# Name: 9060, dtype: object)
# (9062, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["系辦公室、學報工作室等。", "碩士生修業年限為二至四年，畢業學分 24 學分。", "...
# Name: 9062, dtype: object)
# (9100, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["林長壽教授", "美國紐約大學博士", "合聘教師：14 人", "王振男教授", "美...
# Name: 9100, dtype: object)
# (9126, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["普勒測流儀", "全球定位系統", "側掃聲納儀", "深海重絞資訊交流機", "輪盤式...
# Name: 9126, dtype: object)
# (9152, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["樓落成、啟用，院內的辜振甫先生紀念圖書館（圖書 館社會科學資源服務組）亦於 103 年 ...
# Name: 9152, dtype: object)
# (9184, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["臺灣大學臨床醫學研究所博士", "臨床副教授 王秀伯", "臺大醫學院醫學系醫學士 李嘉...
# Name: 9184, dtype: object)
# (9185, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["黃俊達 臺大醫學院醫學系醫學士", "黃聖懿 中國醫藥學院醫學士", "張勝南 臺大臨床...
# Name: 9185, dtype: object)
# (9186, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["臺大醫學院醫學系醫學士 趙家德", "臺大醫學院醫學系醫學士 賀立婷", "成大醫學院醫...
# Name: 9186, dtype: object)
# (9189, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["具前瞻性的移植醫學", "臺大外科先後完成多例腎臟移植", "臺大外科先後完成多例心臟移...
# Name: 9189, dtype: object)
# (9194, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["學術活動", "每週一、三、五上午 7 點 45 分至 8 點 45 分舉行晨會", "...
# Name: 9194, dtype: object)
# (9195, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["仁", "張美惠", "江伯倫", "吳美環", "黃立民教授", "師資", "教授兼...
# Name: 9195, dtype: object)
# (9197, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["學生必修實習課程", "在小兒科住院醫師之指導下在一般及隔離病房、嬰兒室、中重度病房、加...
# Name: 9197, dtype: object)
# (9205, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["臺大醫學院醫學士 期之必修課程", "除設有教學門診", "另對醫學生之教學", "楊長...
# Name: 9205, dtype: object)
# (9206, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["臺大醫學院醫學士、臺大臨床醫學研究所碩 林隆光", "臺大臨床醫學研究所博士 士 柯美蘭...
# Name: 9206, dtype: object)
# (9215, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["范守仁 臺大臨床醫學研究所博士", "林子玉 元智大學機械系醫工組博士 助理教授", "...
# Name: 9215, dtype: object)
# (9247, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["儀", "螢光光譜儀", "表面張力計", "冷凍離心機", "冷凍乾燥機", "高效液...
# Name: 9247, dtype: object)
# (9256, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["培育具多元思考之醫學研究 驗與生物技術等相關領域，表現卓越。",\n"民國 76 年成 ...
# Name: 9256, dtype: object)
# (9313, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["討會、光通訊元件及材料技術研習會", "水性樹脂研討會", "粉體塗料用樹脂研討會", ...
# Name: 9313, dtype: object)
# (9320, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["極製粉設備 學術單位｜工學院｜材料科學與工程學系｜ 高分子暨醫工實驗室", "極高溫陶瓷...
# Name: 9320, dtype: object)
# (9366, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["家公園", "水利署", "工業局", "經建會", "交通部觀光", "生物技術", ...
# Name: 9366, dtype: object)
# (9424, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["薦赴伊利諾大學或德州大學達拉斯分校就讀一 行為研究（3）",\n "論文寫作一（3）",...
# Name: 9424, dtype: object)
# (9467, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["國立臺灣大學電機博士 陳志宏", "美國加州大學柏克萊分校醫學工程博士 李枝宏", "美...
# Name: 9467, dtype: object)
# (9468, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["美國普林斯頓大學博士 陳信樹", "美國伊利諾大學香檳分校電機博士 黃建璋", "美國伊...
# Name: 9468, dtype: object)
# (9476, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["亦積極培養其領袖能力與風範", "光電所在有限資源下，學術研究成果卓越，受到國際學界肯定...
# Name: 9476, dtype: object)
# (9483, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["最卓著的研究團隊之一", "近年性", "亦與光電所合作", "亦與電信所合作", "亦...
# Name: 9483, dtype: object)
# (9555, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["CZ15 CZ15 CZ1 CZ13 臺大醫學院附設醫院 NTU Hospital", ...
# Name: 9555, dtype: object)
# (9605, url                      http://www.aic.bioagri.ntu.edu.tw/
# chunks    ["為使資源有效整合與利用，本院設有共同儀器中心，積極投入各項高科技設備之更新與建置，使研發...
# Name: 9605, dtype: object)
# (9758, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["stream is strengthening moral education.", "...
# Name: 9758, dtype: object)
# (9929, url                 https://ntubeats.ntu.edu.tw/pdf/089.pdf
# chunks    ["place for students to come, have English cam...
# Name: 9929, dtype: object)
# (10046, url                    https://ntubeats.ntu.edu.tw/enews/76
# chunks    ["Taiwan’s oldest popular science magazine, Sc...
# Name: 10046, dtype: object)
# (10147, url                 https://ntubeats.ntu.edu.tw/pdf/085.pdf
# chunks    ["COVID-19 lockdown", "“Filmmaker Bootcamp” Ed...
# Name: 10147, dtype: object)
# (10157, url                 https://ntubeats.ntu.edu.tw/pdf/085.pdf
# chunks    ["Transformation and malfunction analysis, and...
# Name: 10157, dtype: object)
# (10159, url                 https://ntubeats.ntu.edu.tw/pdf/085.pdf
# chunks    ["classmates to express his gratitude to his t...
# Name: 10159, dtype: object)
# (10264, url                 https://ntubeats.ntu.edu.tw/pdf/081.pdf
# chunks    ["BRB", "Steel Panel Damper", "eliminating the...
# Name: 10264, dtype: object)
# (10373, url                 https://ntubeats.ntu.edu.tw/pdf/087.pdf
# chunks    ["Prof. Chou co-published the named SpineFET",...
# Name: 10373, dtype: object)
# (10456, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["學生自治之精神以及學生自治的論述與知識，落實校園民主，堅守臺大自由學風的堡壘。",\n"...
# Name: 10456, dtype: object)
# (10462, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["抗戰勝利，政府接收臺北帝大，理學院正式成立", "理學院設有化學系、地質學系、動物學系與...
# Name: 10462, dtype: object)
# (10469, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["工學院匯集各類的工程、製造、研發等單位而成，共計有木土工程學系、機械工程學系、化學工程學...
# Name: 10469, dtype: object)
# (10507, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["電機資訊、醫學、公衛、生命科學、生資農學等重要科技領域的龐大研究能量", "配合政府的政...
# Name: 10507, dtype: object)
# (10693, url                 https://ntubeats.ntu.edu.tw/pdf/079.pdf
# chunks    ["statistics have shown that it has potential ...
# Name: 10693, dtype: object)
# (10695, url                 https://ntubeats.ntu.edu.tw/pdf/079.pdf
# chunks    ["barriers and the obstacles posed after Taiwa...
# Name: 10695, dtype: object)
# (10705, url       https://epaper.ntu.edu.tw/view.php?listid=184&...
# chunks    ["反戰運動、民權運動", "參加運動的學生並非只是出於「年少輕狂」", "參與之後，也不是...
# Name: 10705, dtype: object)
# (10768, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["國⽴臺灣⼤學簡介 NTU", "臺⼤校地幅員遼闊，分布臺北、宜蘭、 新竹、雲林，以及中部...
# Name: 10768, dtype: object)
# (10824, url       https://www.aca.ntu.edu.tw/WebUPD/aca/Admissio...
# chunks    ["112 學年度傅鐘獎學金大一獲獎學生名單", "一、學院配額(共 55 名)", "文學...
# Name: 10824, dtype: object)
# (10840, url       https://www.jstage.jst.go.jp/article/kaseki/11...
# chunks    ["西部上総層群産クジラ類化石の概要と更新統における鯨類相", "木村敏之", "樽　創",...
# Name: 10840, dtype: object)
# (10842, url       https://www.jstage.jst.go.jp/article/kaseki/11...
# chunks    ["Physeter macrocephalus", "関係も不明である", "図 2A 〜...
# Name: 10842, dtype: object)
# (10843, url       https://www.jstage.jst.go.jp/article/kaseki/11...
# chunks    ["新生児個体（USNM487416）", "左上顎骨腹面観（3D 画像）", "四角は福島...
# Name: 10843, dtype: object)
# (10844, url       https://www.jstage.jst.go.jp/article/kaseki/11...
# chunks    ["本来の形態を保持すると考えられる凹面が確認されるこ ラも上顎骨の幅は明らかに狭いことから...
# Name: 10844, dtype: object)
# (10845, url       https://www.jstage.jst.go.jp/article/kaseki/11...
# chunks    ["マッコウクジラの吻部を構成する上顎骨の背側部", "緻密質 吻基部における上顎骨の断面を...
# Name: 10845, dtype: object)
# (10846, url       https://www.jstage.jst.go.jp/article/kaseki/11...
# chunks    ["結論することはできない．", "予察的な観察では他の属レベルで議論された標本は少ないが，...
# Name: 10846, dtype: object)
# (10847, url       https://www.jstage.jst.go.jp/article/kaseki/11...
# chunks    ["より 球に限られる（Jeffersoet al.2015）．Tsaet al...
# Name: 10847, dtype: object)
# (10848, url       https://www.jstage.jst.go.jp/article/kaseki/11...
# chunks    ["属）の分布がある（Jeffersoet al.2015)．", "西部上総層群か...
# Name: 10848, dtype: object)
# (10852, url       https://www.jstage.jst.go.jp/article/kaseki/11...
# chunks    ["62*CetaceaLMA-F7-3東京都昭島市小宮層前期更新世樽・木村（2023", ...
# Name: 10852, dtype: object)
# (10855, url       https://www.jstage.jst.go.jp/article/kaseki/11...
# chunks    ["よりマイルカ科ハクジラ類化石の産出．群馬県立自然史博物館研究報告，（16），71‒76．...
# Name: 10855, dtype: object)
# (10882, url         https://ntubeats.ntu.edu.tw/pdf/006fulltext.pdf
# chunks    ["derived from a universe has gone.", "neutral...
# Name: 10882, dtype: object)
# (10896, url         https://ntubeats.ntu.edu.tw/pdf/006fulltext.pdf
# chunks    ["recruiting by high-level computer science an...
# Name: 10896, dtype: object)
# (10942, url                 https://ntubeats.ntu.edu.tw/pdf/070.pdf
# chunks    ["Learning government has offered more flexibl...
# Name: 10942, dtype: object)
# (11022, url                 https://ntubeats.ntu.edu.tw/pdf/083.pdf
# chunks    ["to critical issues", "excelled in Taiwan", "...
# Name: 11022, dtype: object)
# (11107, url                 https://ntubeats.ntu.edu.tw/pdf/083.pdf
# chunks    ["15 Calligraphy by Bonded by Passion: Japanes...
# Name: 11107, dtype: object)
# (11251, url         https://ntubeats.ntu.edu.tw/pdf/008fulltext.pdf
# chunks    ["higher presidents and vice presidents from 5...
# Name: 11251, dtype: object)
# (11285, url         https://ntubeats.ntu.edu.tw/pdf/008fulltext.pdf
# chunks    ["NTU alumni allowed the library to renovated ...
# Name: 11285, dtype: object)
# (11511, url       https://my.ntu.edu.tw/assistant/doc/rule106080...
# chunks    ["7 jaar aii", "10617 3b WER BAH Ut Be At Base...
# Name: 11511, dtype: object)
# (11695, url         https://ntubeats.ntu.edu.tw/pdf/018fulltext.pdf
# chunks    ["produce a practical biomedical testing platf...
# Name: 11695, dtype: object)
# (11863, url           https://ntubeats.ntu.edu.tw/enews/003/08.html
# chunks    ["“spectrum,” dissecting light into a myriad o...
# Name: 11863, dtype: object)
# (11914, url                 https://ntubeats.ntu.edu.tw/pdf/066.pdf
# chunks    ["gymnastics", "karate", "billiards", "e-sport...
# Name: 11914, dtype: object)
# (11917, url                 https://ntubeats.ntu.edu.tw/pdf/066.pdf
# chunks    ["anniversary celebration took the stage on Ap...
# Name: 11917, dtype: object)
# (12015, url         https://ntubeats.ntu.edu.tw/pdf/010fulltext.pdf
# chunks    ["Turkey signed lot of experience, knowledge a...
# Name: 12015, dtype: object)
# (12046, url         https://ntubeats.ntu.edu.tw/pdf/010fulltext.pdf
# chunks    ["Taiwan" at NTU, "ways of promoting cooperati...
# Name: 12046, dtype: object)
# (12328, url               https://my.ntu.edu.tw/assistant/doc/2.pdf
# chunks    ["we dE: 10617 2b BBA HE Wh & At BUS E+ H+ : l...
# Name: 12328, dtype: object)
# (12516, url       https://my.ntu.edu.tw/assistant/doc/D104007446...
# chunks    ["we dE: 10617 25b RM BBA HE Wh & At BE E+ H+ ...
# Name: 12516, dtype: object)
# (12526, url       https://ga.ntu.edu.tw/general/main_ch/List.asp...
# chunks    ["國立臺灣大學總務處", "臺大車牌辨識專區", "車牌辨識啟用時間： 校總區平面停車場已...
# Name: 12526, dtype: object)
# (12770, url         https://ntubeats.ntu.edu.tw/pdf/012fulltext.pdf
# chunks    ["Kai-yi Chen, along with seven Taiwanese rice...
# Name: 12770, dtype: object)
# (12857, url                 https://ntubeats.ntu.edu.tw/pdf/074.pdf
# chunks    ["steady facility leaders after graduation.", ...
# Name: 12857, dtype: object)
# (12872, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["國立臺灣大學九十八學年度簡介 National Taiwan University 20...
# Name: 12872, dtype: object)
# (13009, url                 https://ntubeats.ntu.edu.tw/pdf/071.pdf
# chunks    ["address the ceremony on behalf of the indust...
# Name: 13009, dtype: object)
# (13216, url                 https://ntubeats.ntu.edu.tw/pdf/076.pdf
# chunks    ["industry as a practitioner.”", "His efforts ...
# Name: 13216, dtype: object)
# (13239, url                 https://ntubeats.ntu.edu.tw/pdf/076.pdf
# chunks    ["acclaimed list of “Innovators Under 35” is a...
# Name: 13239, dtype: object)
# (13285, url                 https://ntubeats.ntu.edu.tw/pdf/076.pdf
# chunks    ["make social contributions.", \n"On December ...
# Name: 13285, dtype: object)
# (13382, url                    https://ntubeats.ntu.edu.tw/enews/79
# chunks    ["been dedicated to the teaching and research ...
# Name: 13382, dtype: object)
# ...
# chunks    ["70分鐘以上的長劇", "大學部設系時間", "民國84年論文方向商請相關領域教師開設獨...
# Name: 15051, dtype: object)
# (15091, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["合聘教師：15 人", "兼任教師：29 人", "特聘研究講座：9人", "博士學位：...
# Name: 15091, dtype: object)
# (15108, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["研究著重於精神異常症狀的診斷、病理、及治療", "企圖建立一統合之臨床心理學理論", "...
# Name: 15108, dtype: object)
# (15113, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["知覺心理學", "人類學習與認知", "理及腦波監控器", "鼠腦定位儀", "電生理訊...
# Name: 15113, dtype: object)
# (15144, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["已有相當基礎和成果，並為國家培養及儲備眾多的基 商之歡迎與重用。", "為了進一步提昇園...
# Name: 15144, dtype: object)
# (15180, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["及金融系等，可增進本系學生的國際化程度以及拓展 視野。", "師資", "專任教師：38...
# Name: 15180, dtype: object)
# (15256, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["肺癌的研究已有良好基礎", "肝癌的研究已有良好基礎", "鼻咽癌的研究已有良好基礎",...
# Name: 15256, dtype: object)
# (15263, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["李百卿 臺大醫學院醫學系醫學士", "李佩玲 中國醫藥學院醫學士", "林宗哲 臺大醫學...
# Name: 15263, dtype: object)
# (15264, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["臺大醫學院醫學系醫學士 林廷軒", "慈濟大學醫學系醫學士 黃慶昌", "臺大醫學院醫學...
# Name: 15264, dtype: object)
# (15267, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["能分科主任，專責統籌、協調和連絡的工作。", "唐季祿 臺灣大學臨床醫學研究所博士", ...
# Name: 15267, dtype: object)
# (15270, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["儀", "心臟電氣刺激儀", "脈衝電場電泳系統", "神經刺激", "葉志凡", "輔...
# Name: 15270, dtype: object)
# (15272, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["臺灣大學臨床醫學研究所博士陳冠宇", "余家利", "日本東京大學醫學部博士李百卿", ...
# Name: 15272, dtype: object)
# (15276, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["臺北醫學大學醫學系醫學士", "賴祐平", "臺北醫學院醫學士", "本科之教學目標為培...
# Name: 15276, dtype: object)
# (15279, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["郭律成 臺大醫學院醫學系醫學士", "黃博昭 臺大醫學院醫學系醫學士", "級的解剖及生...
# Name: 15279, dtype: object)
# (15280, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["臺大醫學院醫學士", "陸鳳屏", "臺大醫學院醫學系醫學士", "王振泰", "臺灣大...
# Name: 15280, dtype: object)
# (15282, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["臺大醫學院醫學系醫學士 陳泓源", "長庚醫學院醫學士", "學系學生為主", "兼及醫...
# Name: 15282, dtype: object)
# (15290, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["臺大公衛學院預防醫學研究所博士 兼任教師", "專任教師：32 人", "張慶忠 臺灣大...
# Name: 15290, dtype: object)
# (15291, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["張弘偉 臺灣臨床醫學研究所博士", "中央研究院院士", "張恬君 臺灣大學臨床醫學研究...
# Name: 15291, dtype: object)
# (15294, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["年完成心臟手術一萬例", "近年來肺癌及肝癌病例數及成功率均居於世界領導的地位", "關...
# Name: 15294, dtype: object)
# (15295, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["臺灣大學醫學院臨床醫學研究所博士", "教授兼部主任 黃俊升", "臺灣大學醫學院臨床醫...
# Name: 15295, dtype: object)
# (15312, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["跨領域之整合性的精神醫學之臨床及基礎研究", "師資", "副教授兼科主任 黃宗正", ...
# Name: 15312, dtype: object)
# (15315, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["林奕廷", "臺大醫學院醫學士", "博士班課程精神醫學實習（6）", "獨立研究（2）...
# Name: 15315, dtype: object)
# (15318, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["作錄影帶輔助教學，效果良好。", "六年級目前為3星期之選修課程，使學生能熟悉眼科基本檢...
# Name: 15318, dtype: object)
# (15339, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["醫師甄審的變革，本部逐年強化 OSCE center與模擬 吳鋼治 臺大醫學系 6 月通...
# Name: 15339, dtype: object)
# (15352, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["臺大醫學院醫學系醫學士", "臺大醫學工程學研究所博士生", "黃雅萍", "中國醫藥大...
# Name: 15352, dtype: object)
# (15407, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["臺灣大學護理學碩士", "生生活，並鼓勵學生參與社團活動。", "系 主 任 | 胡文郁...
# Name: 15407, dtype: object)
# (15412, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["統，是吸收新知的最佳場所。", "日本高知大學護理學系", "美國加州大學洛杉磯 教授 ...
# Name: 15412, dtype: object)
# (15413, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["普通化學", "微生物學及免疫學", "護理理論基礎", "病理生理學", "進階精神暨...
# Name: 15413, dtype: object)
# (15416, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["本系修業期間為四年", "學生修畢 128 學分可獲理學士學位", "本系學生的通識教育...
# Name: 15416, dtype: object)
# (15419, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["育具多元思考之醫檢及醫學生技管理人才。", "本系研究領域的蓬勃發展以及時代潮流 , 於...
# Name: 15419, dtype: object)
# (15463, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["實驗研究方法", "醫學研究與論文發表", "利用假日上課，期使在職醫師能兼顧課業與工作...
# Name: 15463, dtype: object)
# (15467, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["基礎與臨床醫學整 碩士在職專班 合課程", "實驗研究方法", "醫學研究與論文發表",...
# Name: 15467, dtype: object)
# (15468, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["學生們選修學習的機會", "開設通識課程『毒道之處~看不見的危機』", "開設通識課程『...
# Name: 15468, dtype: object)
# (15527, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["名躍升至第35名，充份顯示出本系在研究教學的表現 在國際上是一流水準並有高知名度。", ...
# Name: 15527, dtype: object)
# (15530, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["紀念獎6人", "校內的獎項有15人獲聘為臺灣大學特聘研究講座：2人", "臺大機194...
# Name: 15530, dtype: object)
# (15550, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["化工及其應用領域相關之圖書、期刊除可從總圖書館", "兼任教師", "空 間材料會議、國...
# Name: 15550, dtype: object)
# (15597, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["來訪及專題演講、不定期舉辦學術研討會", "業環境管理、環境規劃與管理，由指導教授指定選...
# Name: 15597, dtype: object)
# (15624, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["模型試驗", "渦流試驗", "異重流試驗", "彎道試驗", "水庫排砂試驗", "生...
# Name: 15624, dtype: object)
# (15629, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["國立臺灣大學國大學作物學講座", "國立臺灣大學國大學育種學講座", "民國 34年臺灣...
# Name: 15629, dtype: object)
# (15645, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["國科會", "農委會", "衛生署", "中央畜產會", "動植物防疫檢疫局"]\n["...
# Name: 15645, dtype: object)
# (15685, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["倫理及國際視野等綜合素養之生物科技人才為目標",\n "此等人才在我國重點發展之「生物資...
# Name: 15685, dtype: object)
# (15719, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["跨國特色及實務性相關課程", "透過多元的課程設計", "校學生共同互相選課", "藉此...
# Name: 15719, dtype: object)
# (15870, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["美國伊利諾大學香檳校區計算機科學博士 劉致為", "美國普林斯頓大學電機博士 管傑雄",...
# Name: 15870, dtype: object)
# (15880, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["奈米積體電路之實體設計自動化、邏輯合成、計算機會持續此領先領域。", "各種應用積體電路...
# Name: 15880, dtype: object)
# (15893, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["統、社群網路分析、自然語言處理、高等人工智慧", "合聘教師：36人", "特殊之設備需...
# Name: 15893, dtype: object)
# (15901, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["統生物學", "蛋白體數據分析", "醫學資訊領域目前開設行程式設計", "平行與分散式...
# Name: 15901, dtype: object)
# (15921, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["本所畢業學生就業管道包含：法官、律師、公私立機主義之實現與人權保障，在後冷戰時期並非平順...
# Name: 15921, dtype: object)
# (15941, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["典藏豐富之植物、動物、魚類標本館", "黃義侑 臺灣大學博士 教授", "助理教授", ...
# Name: 15941, dtype: object)
# (15946, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["極器", "快速糊液黏度測試儀", "FPLC系統", "單細胞微量螢光計", "單株抗...
# Name: 15946, dtype: object)
# (15954, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["美國馬里蘭大學學院市分校生物工程學博士", "與應用連線：以『基礎研究』為基本，進行『應...
# Name: 15954, dtype: object)
# (15967, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["國立臺灣大學生命科學哲學博士 教學研究設備", "本所位於總校區小椰林大道底，理學院旁的...
# Name: 15967, dtype: object)
# (16002, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["人口與性別研究中心成立迄今，多年來推動與人口、性別研究有關的學術性活動，今後仍將繼續朝下...
# Name: 16002, dtype: object)
# (16053, url                              https://www.bcctaipei.com/
# chunks    ["Latest Jobs", "Sales Manager Account, Client...
# Name: 16053, dtype: object)
# (16123, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["盃，全校各系所球隊齊聚一堂，乃是每年新生最重要的校園生活重頭戲之一。", "臺大登記在案...
# Name: 16123, dtype: object)
# (16131, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["充實或更新設備", "館藏相關圖書逾 100 學與生物兩個理學科", "以及農學、農藝制...
# Name: 16131, dtype: object)
# (16135, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["種及縮影資料、 視聽資料多種", "尚有中西文電子資 料庫十餘種", "可透過臺大校園網...
# Name: 16135, dtype: object)
# (16140, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["2003 年 SARS 疫 病 來 襲，醫 學院、醫院與大學研究團隊，針對 SARS 冠...
# Name: 16140, dtype: object)
# (16332, url                 https://ntubeats.ntu.edu.tw/pdf/086.pdf
# chunks    ["It’s time for him and his teammates to carry...
# Name: 16332, dtype: object)
# (16531, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["己，不僅要在專業上追求卓越，更要多讀中西文化的 院之發展並重，不偏廢人文或理工任何一邊。...
# Name: 16531, dtype: object)
# (16690, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["施金元　台灣大學臨床醫學研究所博士 助理教授", "蔡佳醍　臺大醫學院醫學系醫學士 講師...
# Name: 16690, dtype: object)
# (16691, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["郭律成", "台大醫學院醫學系醫學士", "李佩玲", "中國醫藥學院醫學士", "李宗...
# Name: 16691, dtype: object)
# (16692, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["孫幸筠", "陽明醫學院醫學士", "蔡子修", "台北醫學院醫學士", "丁良文", ...
# Name: 16692, dtype: object)
# (16695, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["郭夢菲", "台灣大學醫學院臨床醫學研究所博士", "許文明", "台灣大學醫學院臨床醫...
# Name: 16695, dtype: object)
# (16701, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["林凱信　臺大醫學院醫學系", "江伯倫　美國加州大學博士", "王主科　臺大臨床醫學研究...
# Name: 16701, dtype: object)
# (16704, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["張道遠", "臺大臨床醫學研究所博士", "李建南", "臺大臨床醫學研究所碩士", "...
# Name: 16704, dtype: object)
# (16710, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["眼科部未來之發展，在醫療方面，將積極引進先進醫療技術，且提昇醫療服務品質。",\n"學術...
# Name: 16710, dtype: object)
# (16730, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["組、毒物學組及創傷醫學組，後來因應臺大醫院 組織重整改分一般急診及緊急醫療組。",\n"...
# Name: 16730, dtype: object)
# (16770, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["之牙醫學進階研習課程，與各類牙科輔佐人員之教育訓練，以改善並提昇我國牙科醫療體系之服務水...
# Name: 16770, dtype: object)
# (16793, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["陳振山", "美國加州大學柏克萊分校博士", "尤春風", "英國克蘭費德科技學院博士"...
# Name: 16793, dtype: object)
# (16937, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["顏嗣鈞", "美國德州大學博士", "林浩雄", "臺灣大學博士", "陳良基", "成...
# Name: 16937, dtype: object)
# (16955, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["機、紅外線能階量測系統", "紅外線吸收光譜量測系統", "光電流雜訊量測系統", "B...
# Name: 16955, dtype: object)
# (16969, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["交換協定，99學年度至100學年度期間，提供本院學生總額一名赴締約學校進行為期一學期的交...
# Name: 16969, dtype: object)
# (16998, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["人數大幅成長", "日間學士班供過於求", "進修學士班面臨進修學士班：係於 86 學年...
# Name: 16998, dtype: object)
# (17008, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["學 理 二、 舉辦國際會議及學術演講，促進國內外學術交流並 論文抽印本及各種研究報告等，...
# Name: 17008, dtype: object)
# (17044, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["臺大立足華人頂尖，邁向世界一流之際", "國際事並負責規劃及執行海外教育計畫", "包括...
# Name: 17044, dtype: object)
# (17190, url         https://ntubeats.ntu.edu.tw/pdf/034fulltext.pdf
# chunks    ["improving public health and helping people l...
# Name: 17190, dtype: object)
# (17193, url         https://ntubeats.ntu.edu.tw/pdf/034fulltext.pdf
# chunks    ["Prof. Chang’s research group are unrivaled i...
# Name: 17193, dtype: object)
# (17306, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["經李濟教授勘察後，判定為舊石器時代人類史前遺址，年代至少在1萬年以上。",\n "錢思亮...
# Name: 17306, dtype: object)
# (17312, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["病理學科", "內科", "外科", "皮膚科", "泌尿科", "小兒科", "婦產科...
# Name: 17312, dtype: object)
# (17559, url         https://ntubeats.ntu.edu.tw/pdf/024fulltext.pdf
# chunks    ["Experience: Do Destinations Matter?”,\n "IHS...
# Name: 17559, dtype: object)
# (17852, url         https://ntubeats.ntu.edu.tw/pdf/004fulltext.pdf
# chunks    ["NTU Library carried out the NTU Digital Taiw...
# Name: 17852, dtype: object)
# (17907, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["園內得到互相尊重，適應群體生活的學習，臺大住宿組核心 空間，同時配合設施更新，也提供了許...
# Name: 17907, dtype: object)
# (17977, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["劉聰桂", "臺大博士", "鄧屬予", "美國南加州大學博士", "賈儀平", "美國...
# Name: 17977, dtype: object)
# (17985, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["微鏡", "綜合水質分析儀", "流速計", "微型氣象站", "土壤測滲器", "自動...
# Name: 17985, dtype: object)
# (18013, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["陳東升　美國明尼蘇達大學博士", "薛承泰　美國威斯康辛大學麥迪生分校博士", "曾嬿芬...
# Name: 18013, dtype: object)
# (18047, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["黃瑞雄　臺灣大學臨床醫學研究所博士", "陳宜君　臺灣大學臨床醫學研究所博士", "王秀...
# Name: 18047, dtype: object)
# (18048, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["廖唯昱　臺大醫學院醫學系醫學士", "郭律成　臺大醫學院醫學系醫學士", "李佩玲　中國...
# Name: 18048, dtype: object)
# (18049, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["江榮人", "高雄醫學院醫學士", "莊志明", "臺大醫學院醫學系醫學士", "蘇登煌...
# Name: 18049, dtype: object)
# (18052, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["吳耀銘　台灣大學醫學院臨床醫學研究所博士", "林本仁　台灣大學醫學院毒理學研究所博士"...
# Name: 18052, dtype: object)
# (18058, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["黃立民", "臺大臨床醫學研究所博士", "陳垣崇", "美國哥倫比亞大學博士", "許...
# Name: 18058, dtype: object)
# (18067, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["利用先進之視聽教學，訓練住院醫師及實習醫學生學習", "使眼科部得以百尺竿頭更進一步，貢...
# Name: 18067, dtype: object)
# (18177, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["日本東京女子醫科大學醫學博士 副教授 蔣以仁", "國立臺灣大學資訊工程博士", "教學...
# Name: 18177, dtype: object)
# (18231, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["合聘教師：17人", "博士班的發展方向與重點在於培育我國「挑戰二 博士學位：25人 ○...
# Name: 18231, dtype: object)
# (18274, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["張靜文", "美國辛辛那提大學環境衛生研究所博士"]\n["公共衛生學院"]\n["陳家...
# Name: 18274, dtype: object)
# (18289, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["陳銘憲", "美國密西根大學安那堡分校計算機工程 博士", "王　暉", "美國密西根州...
# Name: 18289, dtype: object)
# (18373, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["社會科學院經濟系", "研究發展處研究發展委員會", "陳聖賢", "管理學院財金系",...
# Name: 18373, dtype: object)
# (18385, url       https://ntuweb.cloud.ntu.edu.tw/ntuebook/cht/2...
# chunks    ["電機資訊學院電機系", "電機資訊學院電機工程學系", "顏嗣鈞", "電機資訊學院電機...
# Name: 18385, dtype: object)
# (18405, url                 https://ntubeats.ntu.edu.tw/pdf/080.pdf
# chunks    ["shouldn’t feel discouraged, however.", "With...
# Name: 18405, dtype: object)
# (18519, url                 https://ntubeats.ntu.edu.tw/pdf/067.pdf
# chunks    ["projects – miniature, propeller-powered race...
# Name: 18519, dtype: object)
# (18549, url               https://my.ntu.edu.tw/assistant/doc/7.pdf
# chunks    ["we dE: 10617 25b RM BBA HE Wh & At BE E+ H+ ...
# Name: 18549, dtype: object)
# (18560, url         https://ntubeats.ntu.edu.tw/pdf/043fulltext.pdf
# chunks    ["Published by National Taiwan University", "W...
# Name: 18560, dtype: object)
# (18572, url         https://ntubeats.ntu.edu.tw/pdf/043fulltext.pdf
# chunks    ["Engineering in 2007", "Prof. Lin has devoted...
# Name: 18572, dtype: object)
# len(gpt_all_splits): 399719                           url             chunk
# 0  https://www.ac.ntu.edu.tw/  國立臺灣大學農業化學系忘記密碼?

# %%
# gpt_sep_chunk_df.to_csv('document/ChatGPT_washed_data.csv', index=False)

# %%
import pandas as pd
gpt_sep_chunk_df = pd.read_csv('document/ChatGPT_washed_data.csv')
gpt_sep_chunk_df
# Out:
#                                                       url  \
# 0                              https://www.ac.ntu.edu.tw/
# 1                              https://www.ac.ntu.edu.tw/
# 2                              https://www.ac.ntu.edu.tw/
# 3                              https://www.ac.ntu.edu.tw/
# 4                              https://www.ac.ntu.edu.tw/
# ...                                                   ...
# 399714  https://sec.ntu.edu.tw/News_Content_n_1419_sms...
# 399715  https://sec.ntu.edu.tw/News_Content_n_1419_sms...
# 399716  https://sec.ntu.edu.tw/News_Content_n_1419_sms...
# 399717  https://sec.ntu.edu.tw/News_Content_n_1419_sms...
# 399718  https://sec.ntu.edu.tw/News_Content_n_1419_sms...
#
#                                            chunk
# 0                               國立臺灣大學農業化學系忘記密碼?
# 1                                  國立臺灣大學農業化學系首頁
# 2                                國立臺灣大學農業化學系網站導覽
# 3                                 國立臺灣大學農業化學系舊網頁
# 4                                國立臺灣大學農業化學系最新消息
# ...                                          ...
# 399714                            國立臺灣大學秘書室 職員申訴
# 399715                       申訴提出後，申訴人尚需做哪些後續工作？
# 399716  申訴資料送至秘書室後，秘書室會先請相對單位提供書面說明，並籌備召開申評會議等事宜
# 399717             俟時間、地點確定後，發開會通知單邀請申訴人及相對人到會說明
# 399718  故申訴人在此期間，只須準備會議當日之說明及委員可能之詢疑內容即可（各約１０分鐘）
#
# [399719 rows x 2 columns]

# %%
from langchain.document_loaders import DataFrameLoader

loader = DataFrameLoader(gpt_sep_chunk_df, page_content_column="chunk")
docs = loader.load()
# print(docs[0])

print(f'len(gpt_all_splits): {len(docs)} {docs[0]}')
# Out:
# len(gpt_all_splits): 399719 page_content='國立臺灣大學農業化學系忘記密碼?' metadata={'url': 'https://www.ac.ntu.edu.tw/'}

# %%
import numpy as np

l = np.array([len(doc.page_content) for doc in docs])
np.min(l), np.mean(l), np.median(l), np.max(l)
# Out:
# (1, 34.97879760531774, 18.0, 1024)

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceBgeEmbeddings

embeddings = HuggingFaceBgeEmbeddings(model_name = "yentinglin/bert-base-zhtw")
faiss = FAISS.from_documents(docs, embeddings)
faiss.save_local(f'embeddings/all_bert_base_zhtw_chatgpt')
# Out:
# No sentence-transformers model found with name /home/ai2lab/.cache/torch/sentence_transformers/yentinglin_bert-base-zhtw. Creating a new one with MEAN pooling.
# Some weights of BertModel were not initialized from the model checkpoint at /home/ai2lab/.cache/torch/sentence_transformers/yentinglin_bert-base-zhtw and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# raw_data = pd.read_csv('document/clean_content_4.csv')
# faq_df = raw_data[-190:]
# faq_df.head()
# Out:
#                                                     url     timestamp  \
# 2914               https://ntubeats.ntu.edu.tw/enews/95  1.702927e+09
# 2915                 https://www.ch.ntu.edu.tw/esh.html  1.704133e+09
# 2916  https://sec.ntu.edu.tw/news_content_n_1413_sms...  1.704133e+09
# 2917  https://sec.ntu.edu.tw/news_content_n_1422_sms...  1.704133e+09
# 2918  https://sec.ntu.edu.tw/News_Content_n_1423_s_4...  1.704133e+09
#
#                                                 content
# 2914  April 95 Subscribe FEATURES A Warmer Campus: I...
# 2915  跳到主要內容區塊 國立臺灣大學化學系 環境安全衛生 手機版選單 search 搜尋 搜尋 分...
# 2916  跳到主要內容區塊 國立臺灣大學秘書室 校務會議 手機版選單 search 搜尋 搜尋 分享 ...
# 2917  跳到主要內容區塊 國立臺灣大學秘書室 優秀學生出國開會補助 手機版選單 search 搜尋 ...
# 2918  跳到主要內容區塊 國立臺灣大學秘書室 臺大講座 手機版選單 search 搜尋 搜尋 分享 ...

# %%
# from langchain.document_loaders import DataFrameLoader
# from langchain.text_splitter import RecursiveCharacterTextSplitter


# loader = DataFrameLoader(faq_df, page_content_column="content")
# docs = loader.load()

# CHUNK_SIZE = 64
# CHUNK_OVERLAP = 8

# child_splitter = RecursiveCharacterTextSplitter(
#     chunk_size=CHUNK_SIZE, chunk_overlap=CHUNK_OVERLAP, add_start_index=True
# )

# all_splits = child_splitter.split_documents(docs)
# print(f'len(all_splits): {len(all_splits)} {all_splits[0]}')
# Out:
# len(all_splits): 2336 page_content='跳到主要內容區塊 國立臺灣大學化學系 環境安全衛生 手機版選單 search 搜尋 搜尋 分享 上方連結 下方連結 分享' metadata={'url': 'https://www.ch.ntu.edu.tw/esh.html', 'timestamp': 1704133444.8363142, 'start_index': 0}

# %%
# faiss = FAISS.from_documents(all_splits, embeddings)
# faiss.save_local(f'embeddings/faq_bge_large_64_8')

# %% [markdown]
# ### Evaluation Function Def

# %%
import pandas as pd

# testset = pd.read_csv('document/FAQ_ChatGPT.csv')
testset = pd.read_csv('document/FAQ_HyDE.csv')

testset.head(3)
# Out:
#                                                 URL  \
# 0  https://admissions.ntu.edu.tw/zh-hant/apply/faq/
# 1  https://admissions.ntu.edu.tw/zh-hant/apply/faq/
# 2  https://admissions.ntu.edu.tw/zh-hant/apply/faq/
#
#                                 Question  \
# 0            學生身份別之間有什麽差異？我應該如何查詢我的身份別呢？
# 1  學生身份別的不同會帶來甚麼差異？如果我同時符合兩個身份別，那應該如何處理？
# 2                  我現在就讀於其他大學，我可以轉學到臺大嗎？
#
#                                               Answer  \
# 0  學生身份別一共分四種：國際生、僑生、港澳生及陸生。您可以透過境外學位生身份別測驗來查詢自己的...
# 1  根據學生身份別的不同，入學流程、學費、獎助學金、開放的系所及一些相關限制都會有差異。建議您在...
# 2  如您為目前正攻讀學士學位的國際生，請參考國際生二年級入學頁面。至於僑、港澳生，如您目前在臺灣...
#
#                      ChatGPT  \
# 0  學生身份別有哪些類別？我該如何確認自己的身份別呢？
# 1       如果我同時符合兩個身份別，我該如何處理？
# 2      我目前在其他大學就讀，我可以轉學到臺大嗎？
#
#                                        retreival doc  \
# 0  ['to pay tuition? 我應該去哪裡得到學費繳交訊息？ To access yo...
# 1  ['You may have one-on-one or one-on-many consu...
# 2  ['to pay tuition? 我應該去哪裡得到學費繳交訊息？ To access yo...
#
#                                        retreival url  \
# 0  ['http://www.ipcs.ntu.edu.tw/page/about/index....
# 1             ['https://mastertalk.oia.ntu.edu.tw/']
# 2  ['http://www.ipcs.ntu.edu.tw/page/about/index....
#
#                                                 HyDE
# 0  學生身份有多種類別，主要分為全日制學生和非全日制學生。全日制學生是指在學校正式註冊並按照學校...
# 1  如果你同時符合兩個身份別，你可以根據具體情況來處理。首先，你可以評估這兩個身份別對你的重要性...
# 2  當然可以！臺灣大學是臺灣最著名的大學之一，具有卓越的學術聲譽和優秀的教學資源。如果你目前在其...

# %%
def retriever_eval(retriever, k):

    retrieve_urls = []
    
    for idx, query in enumerate(testset['ChatGPT']):
        # print('query:', query)
        docs = retriever.get_relevant_documents(query)
        # print('docs:', docs)
        retrieve_urls.append(sorted([(doc.metadata['url'])for doc in docs]))
    
    correct_cnt = 0
    for idx, d in enumerate(testset.iterrows()):
        if d[1]['URL'] in retrieve_urls[idx]:
            correct_cnt+=1

    print(f'Recall@{k}, ChatGPT Generated Question Accuracy: {correct_cnt/len(testset)}')
    return correct_cnt/len(testset)

def hyde_retriever_eval(retriever, k):

    retrieve_urls = []
    
    for idx, query in enumerate(testset['ChatGPT']):
        # print('query:', query)
        docs = retriever.get_relevant_documents(query+testset['HyDE'][idx])
        # print('docs:', docs)
        retrieve_urls.append(sorted([(doc.metadata['url'])for doc in docs]))
    
    correct_cnt = 0
    for idx, d in enumerate(testset.iterrows()):
        if d[1]['URL'] in retrieve_urls[idx]:
            correct_cnt+=1
    
    print(f'Recall@{k}, ChatGPT Generated Question with HyDE Accuracy: {correct_cnt/len(testset)}')
    return correct_cnt/len(testset)

def retriever_original(retriever, k):

    retrieve_urls = []
    
    for idx, query in enumerate(testset['Question']):
        # print('query:', query)
        docs = retriever.get_relevant_documents(query)
        # print('docs:', docs)
        retrieve_urls.append(sorted([(doc.metadata['url'])for doc in docs]))
    
    correct_cnt = 0
    for idx, d in enumerate(testset.iterrows()):
        if d[1]['URL'] in retrieve_urls[idx]:
            correct_cnt+=1
    # print(f"Correct Answer: {d[1]['URL']}")
    # print(f'Retrieve document urls:')
    # [print(url) for url in retrieve_urls[idx]]
    print(f'Recall@{k}, Original Question Accuracy: {correct_cnt/len(testset)}')
    return correct_cnt/len(testset)

# %% [markdown]
# ### CHUNK TEST

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceBgeEmbeddings

embeddings = HuggingFaceBgeEmbeddings(model_name = "BAAI/bge-large-zh-v1.5")
db = FAISS.load_local('embeddings/all_bge_large_chatgpt', embeddings)

Ks = [1, 5, 10, 20, 50, 100]
# Ks = [100]
# Ks = [1, 5, 10, 20]

for K in Ks:
    retriever = db.as_retriever(search_kwargs={"k": K})
    # retriever_original(retriever, K)
    # retriever_eval(retriever, K)
    hyde_retriever_eval(retriever, K)
# Out:
# Recall@1, ChatGPT Generated Question with HyDE Accuracy: 0.36313868613138683
# Recall@5, ChatGPT Generated Question with HyDE Accuracy: 0.44343065693430656
# Recall@10, ChatGPT Generated Question with HyDE Accuracy: 0.5036496350364964
# Recall@20, ChatGPT Generated Question with HyDE Accuracy: 0.5273722627737226
# Recall@50, ChatGPT Generated Question with HyDE Accuracy: 0.5802919708029197
# Recall@100, ChatGPT Generated Question with HyDE Accuracy: 0.6222627737226277

# %%
# from langchain.vectorstores import FAISS
# from langchain.embeddings import HuggingFaceBgeEmbeddings

# db = FAISS.load_local('embeddings/faq_bge_large_chatgpt', embeddings)

# Ks = [1, 5, 10, 20, 50, 100]
# # Ks = [1, 5, 10, 20]

# for K in Ks:
#     retriever = db.as_retriever(search_kwargs={"k": K})
#     retriever_original(retriever, K)
#     retriever_eval(retriever, K)
#     hyde_retriever_eval(retriever, K)
#     # retriever_original(retriever, K)
# Out:
# Recall@1, Original Question Accuracy: 0.5492700729927007
# Recall@1, ChatGPT Generated Question Accuracy: 0.5711678832116789
# Recall@1, ChatGPT Generated Question with HyDE Accuracy: 0.5091240875912408
# Recall@5, Original Question Accuracy: 0.666058394160584
# Recall@5, ChatGPT Generated Question Accuracy: 0.6733576642335767
# Recall@5, ChatGPT Generated Question with HyDE Accuracy: 0.6332116788321168
# Recall@10, Original Question Accuracy: 0.7007299270072993
# Recall@10, ChatGPT Generated Question Accuracy: 0.7098540145985401
# Recall@10, ChatGPT Generated Question with HyDE Accuracy: 0.6697080291970803
# Recall@20, Original Question Accuracy: 0.7408759124087592
# Recall@20, ChatGPT Generated Question Accuracy: 0.7299270072992701
# Recall@20, ChatGPT Generated Question with HyDE Accuracy: 0.7025547445255474
# Recall@50, Original Question Accuracy: 0.7791970802919708
# Recall@50, ChatGPT Generated Question Accuracy: 0.7755474452554745
# Recall@50, ChatGPT Generated Question with HyDE Accuracy: 0.7609489051094891
# Recall@100, Original Question Accuracy: 0.8138686131386861
# Recall@100, ChatGPT Generated Question Accuracy: 0.8102189781021898
# Recall@100, ChatGPT Generated Question with HyDE Accuracy: 0.8120437956204379

# %%
db = FAISS.load_local('embeddings/faq_bge_large_chatgpt', embeddings)
retriever = db.as_retriever(search_kwargs={"k": 1})
retriever_eval(retriever, 1)
# Out:
# query: 學生身份別有哪些類別？我該如何確認自己的身份別呢？
# docs: [Document(page_content='一、學校裡甚麼身分的人應該參加勞保？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 如果我同時符合兩個身份別，我該如何處理？
# docs: [Document(page_content='能否只填寫一個或兩個呢', metadata={'url': 'http://www.oc.ntu.edu.tw/?page_id=15221'})]
# query: 我目前在其他大學就讀，我可以轉學到臺大嗎？
# docs: [Document(page_content='從臺大如何到中研院？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62775.html'})]
# query: 臺大的教學語言有哪些？
# docs: [Document(page_content='什麼是臺大線上英語課程(Online English Programs)？', metadata={'url': 'https://fltc.fltc.ntu.edu.tw/index.php?action=about&id=28'})]
# query: 臺大提供哪些類別的課程呢？
# docs: [Document(page_content='欲知更多資訊，請見臺大線上課程介紹。', metadata={'url': 'https://fltc.fltc.ntu.edu.tw/index.php?action=about&id=28'})]
# query: 臺大的學習規劃辦公室提供哪些學習支援服務？
# docs: [Document(page_content='國立臺灣大學秘書室 校務發展規劃委員會', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1415_s_4352.html'})]
# query: 我可以在入學後改變專業、修讀輔系或雙主修嗎？
# docs: [Document(page_content='可否選修其他研究所的課程以抵免本所在職專班的畢業學分？', metadata={'url': 'https://www.nd.ntu.edu.tw/News_Content.aspx?n=42&s=609'})]
# query: 作為臺大的境外生，我可以申請到其他國家交換嗎？
# docs: [Document(page_content='學士生申請僅能以學士身分出國交換，碩士生申請僅能以碩士身分出國交換。一旦於 錄取出國交換計畫後辦理畢業、離校等手續者，錄取資格隨即取消。', metadata={'url': 'https://management.ntu.edu.tw/ia/OutgoingExchange/FAQ'})]
# query: 我應該如何申請國立臺灣大學的學位課程？
# docs: [Document(page_content='本所規定在必選學分20學分中，可有六學分以外所（含本所一般生）課程抵免，亦即只要在申請學位論文口試之前，填妥「臺灣大學國家發展研究所碩士在職專班學生修課核可書」（在職專班專區的常用表單區可下載)完成表格後送至所辦即可', metadata={'url': 'https://www.nd.ntu.edu.tw/News_Content.aspx?n=42&s=609'})]
# query: 我可以選擇多少個科系作為我的志願？
# docs: [Document(page_content='可以，您可以填寫少於三個志願。', metadata={'url': 'http://www.oc.ntu.edu.tw/?page_id=15221'})]
# query: 臺大申請學士學位的最低學歷要求是什麽？
# docs: [Document(page_content='以「入學大學同等學力認定標準」第5條、第6條或第7條報考者，依照上述規定，在完成學業後即可取得國立臺灣大學「商學碩士」，惟復旦大學的學位及學歷則需另由復旦大學進行審核，其中的要求包括修課及學歷等規定', metadata={'url': 'https://management.ntu.edu.tw/EMBA/2023NTU-Fudan/FAQ'})]
# query: 申請時是否有任何成績要求？
# docs: [Document(page_content='已有本校成績單之碩士生，以上傳碩士成績單於申請系統為主，但若「交換學生計畫學校一覽表」說明須額外附上學士成績單，請另外上傳學士成績單於指定欄位', metadata={'url': 'https://management.ntu.edu.tw/ia/OutgoingExchange/FAQ'})]
# query: 我需要提交前學歷的畢業證書和完整成績單嗎？
# docs: [Document(page_content='檢附文件中，歷年成績單及英文能力檢定證明錄取後需檢附正本相驗', metadata={'url': 'https://www.forex.ntu.edu.tw/%e5%b8%b8%e8%a6%8b%e5%95%8f%e9%a1%8c-%e7%bf%bb%e8%ad%af%e5%ad%b8%e7%a8%8b/'})]
# query: 語言能力要求是什麽？
# docs: [Document(page_content='其語言能力須獲得授課教師之認可，方得修習', metadata={'url': 'https://www.forex.ntu.edu.tw/%e5%b8%b8%e8%a6%8b%e5%95%8f%e9%a1%8c-%e7%bf%bb%e8%ad%af%e5%ad%b8%e7%a8%8b/'})]
# query: 如果我不符合語言能力要求，但仍希望在臺大學習，我應該怎麼辦？
# docs: [Document(page_content='如何與台大合作?', metadata={'url': 'https://ord.ntu.edu.tw/w/ordntu/Alumnus_20072014431973523?bookmark=21080211363184051'})]
# query: 我的學歷證件不是以中或英文寫成，應該找誰來翻譯？
# docs: [Document(page_content='舉凡各類活動證明、研習證書、競賽獎狀、作品等，足資證明申請者中英文基礎與翻譯能力之相關文件皆可附上', metadata={'url': 'https://www.forex.ntu.edu.tw/%e5%b8%b8%e8%a6%8b%e5%95%8f%e9%a1%8c-%e7%bf%bb%e8%ad%af%e5%ad%b8%e7%a8%8b/'})]
# query: 臺大學位課程的申請時程有哪些？
# docs: [Document(page_content='欲知更多資訊，請見臺大線上課程介紹。', metadata={'url': 'https://fltc.fltc.ntu.edu.tw/index.php?action=about&id=28'})]
# query: 學雜費和生活費用的詳情在哪裡可以找到？
# docs: [Document(page_content='我應該去哪裡得到學費繳交訊息？', metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# query: 臺大是否提供獎學金給境外生？如何申請？
# docs: [Document(page_content='A. 國際學位生、校級交換訪問生在申請臺大入學的時候，有線上申請系統，國際學生都透過該系統進行調查填寫或活動宿舍申請等，因此請提醒國際學生到線上申請系統 Online Application System 查詢', metadata={'url': 'https://oia.ntu.edu.tw/faq'})]
# query: 臺灣的學生可以在念書期間工作嗎？
# docs: [Document(page_content='國立臺灣大學學生探索學分辦法', metadata={'url': 'https://www.aca.ntu.edu.tw/w/aca/UAADService_23060914210219485'})]
# query: 臺大的國際引路人計劃是針對哪些學生設計的？
# docs: [Document(page_content='國立臺灣大學學生探索學分辦法', metadata={'url': 'https://www.aca.ntu.edu.tw/w/aca/UAADService_23060914210219485'})]
# query: 臺大的學生職業生涯發展中心提供哪些服務？
# docs: [Document(page_content='臺灣大學總務處', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=77&uid=104&pid=104'})]
# query: 畢業後，我可以在臺灣找到工作嗎？
# docs: [Document(page_content='如何與台大合作?', metadata={'url': 'https://ord.ntu.edu.tw/w/ordntu/Alumnus_20072014431973523?bookmark=21080211363184051'})]
# query: 我想參觀臺大的校園，有提供校園導覽服務嗎？
# docs: [Document(page_content='有的，若您對臺大尚不熟悉，歡迎申請基本套裝行程，本行程以戶外校園為主，不包括室內博物館，如需搭配室內博物館，需另外預約，詳情請參考網頁「校園導覽說明」。', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62778.html'})]
# query: 我是本校學生，我想知道關於領取/換發學生證（遺失補申請）、上課證，申請成績單，申請在學證明，休學、復學的申請問題，以及離校手續，應該找註冊組還是研教組？
# docs: [Document(page_content='我是本校學生，請問有關 (1)領取/換發學生證（遺失補申請）、上課證；(2)申請成績單；(3)申請在學證明；(4)休學、復學 的申請問題；(5)離校手續？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62438.html'})]
# query: 我想報名轉學考試，應該到哪個辦公室？
# docs: [Document(page_content='我想報名轉學考試，應該到哪間辦公室？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62435.html'})]
# query: 我該找哪個單位辦理獎學金申請、就學貸款、學雜費減免、學生事病假單、學生保險、以及填寫失物招領？
# docs: [Document(page_content='我想申請獎學金、辦理就學貸款、學雜費減免、學生事病假單、學生保險、填寫失物招領？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62427.html'})]
# query: 我該找哪個單位申請社團活動、張貼海報等事宜？
# docs: [Document(page_content='我想要申請社團活動、張貼海報……等', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62751.html'})]
# query: 我是本校畢業的校友，我該去哪裡辦理校友證、校友捐贈、協尋畢業校友、參加校友活動？
# docs: [Document(page_content='我是本校畢業的校友，請問申辦校友證、校友捐贈、協尋畢業校友、參加校友活動?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62752.html'})]
# query: 我想申請校園場地拍攝（如雜誌社報導或拍婚紗等），應該聯絡哪個單位？
# docs: [Document(page_content='我想申請校園場地拍攝（如雜誌社報導或拍婚紗等），該連絡哪個單位?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62753.html'})]
# query: 我是本校成員，我應該去哪裡申請汽機車腳踏車停車證並領取？
# docs: [Document(page_content='我是本校成員，請問申請汽機車腳踏車停車證及領取地點?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62754.html'})]
# query: 9.我是廠商，請問如何領取標單、進行開標和參與採購案？
# docs: [Document(page_content='我是廠商，請問領取標單、開標、採購案?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62755.html'})]
# query: 我是外國學生，想了解有關入學、國際學生、交換學生申請的事務，應該找哪個部門？
# docs: [Document(page_content='我是外國學生，請問有關入學、國際學生、交換學生申請各項事務？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62756.html'})]
# query: 11.我是外籍生/大陸生，請問外籍生/大陸生相關問題。
# docs: [Document(page_content='我是僑生/陸生，請問僑生/陸生相關問題。', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62757.html'})]
# query: 我該找誰調閱本校的公文檔案？
# docs: [Document(page_content='我需要調閱本校的公文檔案?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62758.html'})]
# query: 我可以在哪裡索取本校的中英文簡介？
# docs: [Document(page_content='我想要索取本校中英文簡介?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62759.html'})]
# query: 請問展書樓保管組動產股的網頁在哪裡可以找到相關位置資訊？
# docs: [Document(page_content='請洽展書樓保管組動產股，相關位置請參考保管組網頁。', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62760.html'})]
# query: 15. 我要寄信給臺大某單位，請問該送到哪裡？收發室在哪？
# docs: [Document(page_content='有信件要給臺大某單位，請問要送到哪裡？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62761.html'})]
# query: 16. 我的自行車被拖吊了，應該怎麼處理？
# docs: [Document(page_content='我的腳踏車被拖吊該怎麼辦？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62765.html'})]
# query: 在校園內遇到危險時，應該聯絡哪個電話號碼？
# docs: [Document(page_content='在校園內遇到危險，怎麼辦？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62766.html'})]
# query: 我想參加某個會議或活動，你能給我一些相關資訊嗎？
# docs: [Document(page_content='我有參加某個會議或活動，請問相關資訊?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62767.html'})]
# query: 我可以在臺大借用場地舉辦考試或活動嗎？
# docs: [Document(page_content='我想借用臺大場地舉辦考試或活動?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62768.html'})]
# query: 請問我可以在哪裡找到有關語言學習相關課程（如中文、英文、日文、韓文等）的資訊？
# docs: [Document(page_content='請問語言學習相關課程（學中、英、日、韓等語文）', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62769.html'})]
# query: 請問在哪些地方可以找到付費影印服務？
# docs: [Document(page_content='請問哪裡有付費影印?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62771.html'})]
# query: 我想知道在臺大裡面有沒有機器可以拍大頭照？
# docs: [Document(page_content='我急需拍攝大頭照，臺大裡面有機器嗎？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62772.html'})]
# query: 請問本校的哺（集）乳室在哪裡？
# docs: [Document(page_content='23.請問本校有哺（集）乳室嗎?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62773.html'})]
# query: 我想參觀學校裡面的廟，該怎麼找到它的位置？
# docs: [Document(page_content='我想參觀學校裡面的廟，請問要怎麼走？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62774.html'})]
# query: 如何從臺大到中研院？
# docs: [Document(page_content='從臺大如何到中研院？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62775.html'})]
# query: 26. 臺大的「國際會議廳」在哪裡？
# docs: [Document(page_content='臺大的「國際會議廳」在哪？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62776.html'})]
# query: 27.我在哪裡可以找到校園內的餐廳資訊？
# docs: [Document(page_content='校園內哪裡可以用餐？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62785.html'})]
# query: 28.有關兵役問題（含緩徵、儘招、役期折抵等），應該聯繫哪個部門？
# docs: [Document(page_content='有關兵役問題（含緩徵、儘招、役期折抵等）', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_81983.html'})]
# query: 請問我可以在哪裡查詢校區間及中研院學術交通車的時間表和候車處呢？
# docs: [Document(page_content='校區間及中研院學術交通車時間表、候車處？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_81984.html'})]
# query: 我想申請教職員宿舍或學生宿舍，應該找哪個單位？
# docs: [Document(page_content='申請教職員宿舍、學生宿舍等事宜', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_81987.html'})]
# query: 31. 有關遊覽車停放申請，如果我們需要搭乘遊覽車前來，需要提供車號及聯絡人等資料，最晚要在多久之前提供？
# docs: [Document(page_content='有關遊覽車停放申請', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_216122.html'})]
# query: 如何規劃行程？由誰來規劃？
# docs: [Document(page_content='如何規劃行程？誰來規劃？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_s_62777.html'})]
# query: 你們提供套裝行程嗎？
# docs: [Document(page_content='你們有套裝行程嗎？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62778.html'})]
# query: 導覽路線是否僅限於校總區？
# docs: [Document(page_content='導覽路線僅限校總區嗎？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62779.html'})]
# query: 4. 我想要登記到我想要的時段，但是沒有名額了，該怎麼辦？
# docs: [Document(page_content='我一直無法登記到我想要的時段，怎麼辦？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62780.html'})]
# query: 導覽員是否都是在學學生或修習服務課程的學生？
# docs: [Document(page_content='帶校園導覽的導覽員，都是在學學生嗎？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62781.html'})]
# query: 我是高中老師，想順便安排校園導覽還有科系座談，該如何處理呢？
# docs: [Document(page_content='我是高中老師，想順便安排校園導覽還有科系座談，請問該怎麼作呢？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62782.html'})]
# query: 7. 是否可以要求導覽員是特定科系的學生或某高中的校友？
# docs: [Document(page_content='可以指定導覽員是某科系學生或某高中校友嗎？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62783.html'})]
# query: 如何停放遊覽車？
# docs: [Document(page_content='有關遊覽車停放申請', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_216122.html'})]
# query: 9. 在校園內哪裡可以用餐？
# docs: [Document(page_content='校園內哪裡可以用餐？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62785.html'})]
# query: 10. 參觀時是否有安排上洗手間的時間？
# docs: [Document(page_content='導覽中有安排上洗手間的時間嗎？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62786.html'})]
# query: 我們是一個旅行社，可以申請校園導覽嗎？
# docs: [Document(page_content='我們是個人/旅行社/私人公司辦活動，可以申請校園導覽嗎？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62787.html'})]
# query: 我們團隊有200人，但只需要一位導覽員，可以不用擴音器隨便講講嗎？
# docs: [Document(page_content='在不干擾本校教學研究活動的前提下，目前我們的導覽員皆不使用擴音機，所以為了維護導覽品質（人數太多時導覽品質將下降），同時保護導覽員的嗓門，建議您還是依照現有規定申請，讓我們共同維護臺大的環境品質，也確保有愉快的臺大之旅。', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62788.html'})]
# query: 參觀校園時應該注意什麼穿著？
# docs: [Document(page_content='請問參觀校園該如何穿著?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62789.html'})]
# query: 14. Do you offer guided tours in languages other than English?
# docs: [Document(page_content='14.請問你們有提供英文以外的外語導覽服務嗎?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62790.html'})]
# query: 我想參觀台大校園，可以旁聽課程嗎？
# docs: [Document(page_content='我考慮未來成為台大學生，最近將會參觀台大校園，請問我可以旁聽課程嗎?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62791.html'})]
# query: 16.我想在台大校園裡四處走走，除了走路以外，還有其他交通工具可以選擇嗎?
# docs: [Document(page_content='我想在台大校園裡四處走走，請問除了走路還有其他交通工具可以選擇嗎?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62792.html'})]
# query: 當我在台灣大學訪問時，我可以在哪裡上網？
# docs: [Document(page_content='當我訪問台灣大學時，請問我可以在哪裡上網?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62793.html'})]
# query: 19. 可以告訴我導覽員的聯絡方式嗎？
# docs: [Document(page_content='可以指定導覽員是某科系學生或某高中校友嗎？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62783.html'})]
# query: 哪些人應該參加勞保？
# docs: [Document(page_content='一、學校裡甚麼身分的人應該參加勞保？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 二、如果我只工作不超過3個月或每週工時不滿12小時，我需要參加健保嗎？
# docs: [Document(page_content='二、健保ㄧ定要參加嗎？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 學生兼任助理需要向誰詢問身分認定及加保事宜？
# docs: [Document(page_content='三、學生兼任助理需要加保嗎？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 辦理勞健保加保及勞退金提繳需要檢附哪些文件？
# docs: [Document(page_content='四、辦理勞健保加保及勞退金提繳要檢附哪些資料？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 加保有沒有時效性？應該在什麼時候辦理加保手續？
# docs: [Document(page_content='五、加保有沒有時效性？甚麼時候應該辦理加保？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 保險可以追溯嗎？如果因為疏忽，未在到職當天申報加保，可以用補繳保險費的方式，追溯從到職當天加保嗎？
# docs: [Document(page_content='六、保險可以追溯嗎？如果因為疏忽，未在到職當天申報加保，可以用補繳保險費的方式，追溯從到職當天加保嗎？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 離職前應該在什麼時候填寫退保申請書？
# docs: [Document(page_content='七、離職前，保險要注意甚麼事？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 如果聘僱期限屆滿後，我還會繼續在學校擔任其他職務，該如何申請延長保險期限？
# docs: [Document(page_content='八、聘僱期限(保險期限)屆滿時，如果還會繼續在學校擔任其他職務，保險該如何申請延長？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 加保期間如有薪資調整，應該如何處理？
# docs: [Document(page_content='九、加保期間，如果薪資有調整，應該如何處理？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 符合加保資格的勞工在本校參加的保險分為哪幾種？保險費包含哪些項目？
# docs: [Document(page_content='十、符合加保資格的勞工，在本校參加的保險分為哪幾種？又保險費包含哪些項目？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 我的薪資要如何對照投保金額？勞健保及勞退金額對照表在哪裡下載？
# docs: [Document(page_content='勞健保及勞退金額對照表在哪裡下載？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 我(個人)和學校(雇主)分別需要支付多少保險費用？
# docs: [Document(page_content='十二、我(個人)跟學校(雇主)分別要繳納多少保險費？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 薪資不固定的勞工應如何計算投保金額？
# docs: [Document(page_content='十三、薪資不固定的勞工，要如何計算投保金額？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 部分工時人員和臨時人員有什麼區別？
# docs: [Document(page_content='十四、部分工時人員與臨時人員有什麼不同？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 外籍人士可以提繳勞工退休金嗎？
# docs: [Document(page_content='十六、除了本國人 ，外籍人士可以提繳勞工退休金嗎？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 陸生在臺就學期間，是否可以在本校兼任工作？是否可以在本校加入勞保？
# docs: [Document(page_content='十七、陸生可否在本校兼任工作？可否在本校加勞保？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 學生兼任勞僱型助理是否有兼職個數的限制？同時兼任多個職務應如何辦理加保？
# docs: [Document(page_content='十八、學生兼任勞僱型助理，是否有兼職個數的限制？同時兼任多個職務應如何辦理加保？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 請問參觀農場是否需要入住或參加套裝行程？如何預約報名梅峰自然生態體驗營？ (2014.01.20)
# docs: [Document(page_content='你們有套裝行程嗎？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62778.html'})]
# query: 請問進入農場住宿是否可以不參加套裝行程？ (2014.01.20)
# docs: [Document(page_content='你們有套裝行程嗎？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62778.html'})]
# query: 每年臺大山地實驗農場(梅峰農場)有哪些活動可以參觀？
# docs: [Document(page_content='國立臺灣大學生物資源暨農學院附設山地實驗農場', metadata={'url': 'https://mf.ntu.edu.tw/News_toggle_n_1395_sms_10293.html'})]
# query: 梅峰自然生態體驗營需要多少人才能報名？ (2023.01.04)
# docs: [Document(page_content='申請資格：全國大專院校大學部在學學生（非109學年度應屆畢業生），對於海洋研究有興趣者，均可報名參加。', metadata={'url': 'http://www.oc.ntu.edu.tw/?page_id=15221'})]
# query: 主婦聯盟與里仁是否有販售？臺大是否有販售？販售什麼？(2016.10.18)
# docs: [Document(page_content='臺大簡介及概況內容有何不同？如何區分？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1424_sms_10362_s_4408.html'})]
# query: 請問茶葉和果品在栽種和下藥過程中是否使用農藥和化學肥料？
# docs: [Document(page_content='科技部、農委會等機關皆有產學合作計畫', metadata={'url': 'https://ord.ntu.edu.tw/w/ordntu/Alumnus_20072014431973523?bookmark=21080211363184051'})]
# query: 7. 如何延長百合水仙切花的觀賞期？
# docs: [Document(page_content='study, we will evaluate this hypothesis via investigating variation in spawning seasons for common tidepool reef fishes between the NE and S coasts of Taiwan.', metadata={'url': 'http://www.oc.ntu.edu.tw/?page_id=15221'})]
# query: 8.明日葉根部商品是否可供食用？(2016.10.18)
# docs: [Document(page_content='本研究旨在測量表水層中浮游植物在白天與晚上的被攝食率來驗證這個假說。', metadata={'url': 'http://www.oc.ntu.edu.tw/?page_id=15221'})]
# query: 明日葉過度食用是否有副作用？
# docs: [Document(page_content='白天真的不懂夜的黑? – 浮游動物的晝夜垂直遷移對浮游植物被攝食率的影響', metadata={'url': 'http://www.oc.ntu.edu.tw/?page_id=15221'})]
# query: 如何判斷甜菜根是否壞掉？
# docs: [Document(page_content='每張 PCMCIA 卡會提供監測軟體，並以 SNR 值來判定收訊品質。如果收訊品質不佳，可加裝2.5 dBi 室內增強型天線。加裝增強型天線的效用在於加強 SNR 值的強度，減少雜訊及封包遺失', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 11. 茶葉的有機或無毒性質？春冬茶的採摘時間？茶種植地點？有機或無毒？深焙或淺焙？
# docs: [Document(page_content='一些常見的條件如下:', metadata={'url': 'https://ord.ntu.edu.tw/w/ordntu/Alumnus_20072014431973523?bookmark=21080211363184051'})]
# query: 12. 臺灣大學醫學院的畢業校友是否可以享受員工打折優惠？(2016.10.18)
# docs: [Document(page_content='依「國立臺灣大學職員申訴辦法」第12條規定辦理', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1419_sms_10357_s_4382.html'})]
# query: 我想要索取環境教育時數，應該怎麼做呢？
# docs: [Document(page_content='教育訓練項目及時數？', metadata={'url': 'https://www.ch.ntu.edu.tw/esh.html'})]
# query: Q：為何要限制探索學分的適用對象只限於1~2年級的學士班學位生？
# docs: [Document(page_content='探索學分簡介', metadata={'url': 'https://www.aca.ntu.edu.tw/w/aca/UAADService_23060914210219485'})]
# query: Q：探索學分的申請有哪些課程是不符合資格的？
# docs: [Document(page_content='探索學分簡介', metadata={'url': 'https://www.aca.ntu.edu.tw/w/aca/UAADService_23060914210219485'})]
# query: Q：為什麼主修及雙主修課程不能算作探索學分？
# docs: [Document(page_content='雙主修生的學系認定規則與前述相同，如中文系學生於112-2學期時已具有經濟系雙主修資格，則中文系及經濟系課程皆視為該生的專業課程，不得申請為探索學分，但若學生在申請探索學分前已被核准放棄經濟系雙主修身分，則經濟系課程不再視為專業課程，可申請認列為探索學分。', metadata={'url': 'https://www.aca.ntu.edu.tw/w/aca/UAADService_23060914210219485'})]
# query: Q：如果一位學生在112-2學期時已經具有經濟系的雙主修資格，那麼他還能申請中文系的課程作為探索學分嗎？
# docs: [Document(page_content='雙主修生的學系認定規則與前述相同，如中文系學生於112-2學期時已具有經濟系雙主修資格，則中文系及經濟系課程皆視為該生的專業課程，不得申請為探索學分，但若學生在申請探索學分前已被核准放棄經濟系雙主修身分，則經濟系課程不再視為專業課程，可申請認列為探索學分。', metadata={'url': 'https://www.aca.ntu.edu.tw/w/aca/UAADService_23060914210219485'})]
# query: Q：修習學期課程是否可以申請探索學分？
# docs: [Document(page_content='探索學分', metadata={'url': 'https://www.aca.ntu.edu.tw/w/aca/UAADService_23060914210219485'})]
# query: Q：如果暑期課程被認列為探索學分，但費用未繳交，是否需要追繳？
# docs: [Document(page_content='探索學分', metadata={'url': 'https://www.aca.ntu.edu.tw/w/aca/UAADService_23060914210219485'})]
# query: Q：大一至大二修業期間，申請探索學分的課程合計最多可以有多少學分？
# docs: [Document(page_content='探索學分', metadata={'url': 'https://www.aca.ntu.edu.tw/w/aca/UAADService_23060914210219485'})]
# query: Q：探索學分申請的時間是什麼時候？
# docs: [Document(page_content='探索學分', metadata={'url': 'https://www.aca.ntu.edu.tw/w/aca/UAADService_23060914210219485'})]
# query: Q：如何申請探索學分？何時可生效？如何確定已完成申請？
# docs: [Document(page_content='探索學分', metadata={'url': 'https://www.aca.ntu.edu.tw/w/aca/UAADService_23060914210219485'})]
# query: Q：探索學分申請後是否可以要求恢復成原來的成績計算方式？
# docs: [Document(page_content='探索學分', metadata={'url': 'https://www.aca.ntu.edu.tw/w/aca/UAADService_23060914210219485'})]
# query: Q：探索學分制度是否會導致某些課程的選修人數急劇增加或者其他課程的選修人數減少？
# docs: [Document(page_content='探索學分', metadata={'url': 'https://www.aca.ntu.edu.tw/w/aca/UAADService_23060914210219485'})]
# query: Q：探索學分是否可以用於修習任何課程？
# docs: [Document(page_content='探索學分', metadata={'url': 'https://www.aca.ntu.edu.tw/w/aca/UAADService_23060914210219485'})]
# query: Q：作為一位老師，探索學分對我的影響主要是什麼？
# docs: [Document(page_content='探索學分', metadata={'url': 'https://www.aca.ntu.edu.tw/w/aca/UAADService_23060914210219485'})]
# query: Q：教務處是否會為探索學分制度開發一個線上申請系統？
# docs: [Document(page_content='國立臺灣大學學生探索學分辦法', metadata={'url': 'https://www.aca.ntu.edu.tw/w/aca/UAADService_23060914210219485'})]
# query: 請問新版公文資訊系統的網址是什麼？
# docs: [Document(page_content='公文系統', metadata={'url': 'https://ga.ntu.edu.tw/doc/main_ch/faqList.aspx?faq=160&uid=1393&pid=1393'})]
# query: 新版公文系統上線的日期是什麼時候？
# docs: [Document(page_content='公文系統', metadata={'url': 'https://ga.ntu.edu.tw/doc/main_ch/faqList.aspx?faq=160&uid=1393&pid=1393'})]
# query: 新版公文系統最重要的改變是什麼？
# docs: [Document(page_content='公文系統', metadata={'url': 'https://ga.ntu.edu.tw/doc/main_ch/faqList.aspx?faq=160&uid=1393&pid=1393'})]
# query: 新版公文系統的公布欄清單網址是什麼？
# docs: [Document(page_content='公文系統', metadata={'url': 'https://ga.ntu.edu.tw/doc/main_ch/faqList.aspx?faq=160&uid=1393&pid=1393'})]
# query: 如何在第一次使用自然人憑證時進行線上簽核操作？
# docs: [Document(page_content='只要於e自學空間服務櫃檯出示您的臺大證件，學習者即可於本空間自行選位開始線上學習或觀賞影片。', metadata={'url': 'https://fltc.fltc.ntu.edu.tw/index.php?action=about&id=28'})]
# query: 為何需要有文號才能點選〔流程設定〕？為何需要有文號才能設定夾帶附件?為何需要有文號才能找到改為〔紙本簽核〕的功能鍵?
# docs: [Document(page_content='在「一般」頁面，可以看到「允許程式存取」的選項，找到Pulse Secure並允許存取', metadata={'url': 'https://ccnet.ntu.edu.tw/vpn/faq.html?fbclid=IwAR0ymKoVH-SHCYwiHKC_tq0yhKBgG-Sti82SDDEDB4JFnaJkLKGdjnBeFgE#faq1-1'})]
# query: 辦理公文函稿時，如何選取檔號？
# docs: [Document(page_content='如果有公文追蹤碼或校收文號時，可直接在公文系統 http://doc.ntu.edu.tw/track/track_test/trackQuery.asp查詢公文流程。', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1431_s_4429.html'})]
# query: 如何讓同事們查看從「公布欄清單」收到的校內公文？
# docs: [Document(page_content='如果有公文追蹤碼或校收文號時，可直接在公文系統 http://doc.ntu.edu.tw/track/track_test/trackQuery.asp查詢公文流程。', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1431_s_4429.html'})]
# query: 公文系統的校外公文如何進行簽收？
# docs: [Document(page_content='如果有公文追蹤碼或校收文號時，可直接在公文系統 http://doc.ntu.edu.tw/track/track_test/trackQuery.asp查詢公文流程。', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1431_s_4429.html'})]
# query: 校內的公文是否只能從「公布欄清單」收取，不再有紙本公文？
# docs: [Document(page_content='校務會議提案單各欄位是否都要填寫？', metadata={'url': 'https://sec.ntu.edu.tw/news_content_n_1413_sms_10351_s_4343.html'})]
# query: 公文系統實施後，校內單位的公文可以直接在公布欄清單中加註意見或以便利貼方式寫意見嗎？
# docs: [Document(page_content='校務會議提案單各欄位是否都要填寫？', metadata={'url': 'https://sec.ntu.edu.tw/news_content_n_1413_sms_10351_s_4343.html'})]
# query: 有關公文的檔號及歸檔問題，應該撥打哪個客服電話？
# docs: [Document(page_content='如果有公文追蹤碼或校收文號時，可直接在公文系統 http://doc.ntu.edu.tw/track/track_test/trackQuery.asp查詢公文流程。', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1431_s_4429.html'})]
# query: 為什麼從校外無法連線公文系統？
# docs: [Document(page_content='公文系統常見問題', metadata={'url': 'https://ga.ntu.edu.tw/doc/main_ch/faqList.aspx?faq=160&uid=1393&pid=1393'})]
# query: 系統操作有問題，可以向誰尋求幫助？
# docs: [Document(page_content='其他環安衛問題可以找誰？', metadata={'url': 'https://www.ch.ntu.edu.tw/esh.html'})]
# query: 研究計畫案合約書送出後，內容遭對方修改，需要進行哪些印章程序？
# docs: [Document(page_content='列印一份修訂完成之論文（不必裝訂）、口試委員審定書正本，和國立臺灣大學學位論文學術倫理暨原創性比對聲明書等三項送至所辦。', metadata={'url': 'https://www.nd.ntu.edu.tw/News_Content.aspx?n=70&s=661'})]
# query: 經辦公文時間流程掌控為何？
# docs: [Document(page_content='如果有公文追蹤碼或校收文號時，可直接在公文系統 http://doc.ntu.edu.tw/track/track_test/trackQuery.asp查詢公文流程。', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1431_s_4429.html'})]
# query: 歸檔案件退回承辦單位之處理狀況是什麼？
# docs: [Document(page_content='如果收到不屬於自己單位的校收公文時，可以上網http://www.ga.ntu.edu.tw/documentation/download_01.jsp?s=1&dd_id=DD1195191977768&npage=3&selctid=&selid=�下載「退文分辦單」，填妥後請主管蓋章，然後連同公文一起送交文書組申請改分其他單位。', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1431_sms_10369_s_4430.html'})]
# query: 如何編寫頁碼？
# docs: [Document(page_content='網頁功能', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62753.html'})]
# query: 公文如何存檔？
# docs: [Document(page_content='如果公文找不到了該怎麼辦？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1430_sms_10368_s_4428.html'})]
# query: 如何實現公文減文的目標？
# docs: [Document(page_content='公文系統', metadata={'url': 'https://ga.ntu.edu.tw/doc/main_ch/faqList.aspx?faq=160&uid=1393&pid=1393'})]
# query: 機密公文的傳遞方式是什麼？
# docs: [Document(page_content='資料傳送的可靠性為何', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 發文附件應如何標示？
# docs: [Document(page_content='提案如果有附件，需要印幾份給代表？', metadata={'url': 'https://sec.ntu.edu.tw/news_content_n_1413_sms_10351_s_4344.html'})]
# query: 公文夾的使用應該注意哪些事項？
# docs: [Document(page_content='如果公文找不到了該怎麼辦？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1430_sms_10368_s_4428.html'})]
# query: 「速別」的使用方式是什麼？
# docs: [Document(page_content='無線區域網路的資料傳輸速率為何', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 如何區分「先簽後稿」及「簽稿併陳」？
# docs: [Document(page_content='若欲提供和稿件相關的圖片或照片，該如何處理？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1428_sms_10366_s_4425.html'})]
# query: 何謂「簽」、「先簽後稿」、「簽稿併陳」及「以稿代簽」?
# docs: [Document(page_content='若欲提供和稿件相關的圖片或照片，該如何處理？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1428_sms_10366_s_4425.html'})]
# query: 文稿製作時應注意哪些常見疏漏？
# docs: [Document(page_content='公文系統常見問題', metadata={'url': 'https://ga.ntu.edu.tw/doc/main_ch/faqList.aspx?faq=160&uid=1393&pid=1393'})]
# query: 何謂「文別」及其標示位置？
# docs: [Document(page_content='為避免廠商濫用校名、校徽等與學校有關聯之文字或圖片，總務處訂有「商標使用申請及管理規則」。', metadata={'url': 'https://ord.ntu.edu.tw/w/ordntu/Alumnus_20072014431973523?bookmark=21080211362884042'})]
# query: 使用〔簡易辦文〕方式簽辦公文的注意事項有哪些？
# docs: [Document(page_content='不需蓋附件章送秘書室，附件電子檔亦需同時e-mail予秘書室承辦人。', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1412_sms_10350_s_4336.html'})]
# query: 進口免稅令是否適用於由廠商向國外進口貨品，再開立國內發票銷售予學校的案件？
# docs: [Document(page_content='免稅', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 如果貨物已抵達海關，但發現未辦理免稅手續，應該如何處理？
# docs: [Document(page_content='免稅', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 哪些物品可以申請免稅令，以台大名義進口的所有物品都可以嗎？
# docs: [Document(page_content='免稅', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 免稅令的用途是什麼？申辦的時機是什麼？申辦的流程是怎樣的？
# docs: [Document(page_content='免稅', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 報關提貨與押款提貨有何區別？
# docs: [Document(page_content='結案報帳', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 如果免稅令尚未核發，是否可以先繳納稅金（關稅及營業稅）辦理結關提貨，然後再報帳？
# docs: [Document(page_content='免稅', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 免稅令的幣別可以是台幣嗎？
# docs: [Document(page_content='免稅', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 進口教學研究用品，除購買外，還有哪些因素可以申請免稅？
# docs: [Document(page_content='免稅', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 進口教學研究用品時，是否只能透過免稅令來免除稅賦？
# docs: [Document(page_content='免稅', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 如何根据付款条件来确定价格条款（price term）？
# docs: [Document(page_content='一些常見的條件如下:', metadata={'url': 'https://ord.ntu.edu.tw/w/ordntu/Alumnus_20072014431973523?bookmark=21080211363184051'})]
# query: 開立信用狀的案件，何時會收到「領取進口單據通知書」及其所附之押匯單據要如何保存？
# docs: [Document(page_content='原措施之學校或主管機關依法應以可供存證查核之方式送達其措施於 申訴人者，以該送達之日為知悉日', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1418_sms_10356_s_4371.html'})]
# query: 國際貿易的價格條件如CIP、DAP…，其運費、保險費、通關費及稅捐的歸屬為何？風險及物權移轉點在何時？
# docs: [Document(page_content='國貿常見問題', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=76&uid=104&pid=104'})]
# query: 對於不熟悉國際貿易的情況下，有哪些價格條件可以降低採購風險？
# docs: [Document(page_content='國貿常見問題', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=76&uid=104&pid=104'})]
# query: DAP和CIP報價的稅費歸屬和主要差異是什麼？
# docs: [Document(page_content='稅前金額。', metadata={'url': 'https://sec.ntu.edu.tw/news_content_n_1421_sms_10359_s_4390.html'})]
# query: 賣方要負擔進口關稅及營業稅，就無需辦理進口免稅令了，妥當嗎？
# docs: [Document(page_content='免稅', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 透過信用狀的付款方式，如果領取進口單據通知書有瑕疵，應該如何處理後續的付款事宜？
# docs: [Document(page_content='140.112.4.231的憑證，會有安全性警告，請按是繼續處理', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 在訂有分期付款條件的信用狀中，當「到貨後」或「驗收合格後」應如何處理付款事宜？
# docs: [Document(page_content='驗收', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=80&uid=104&pid=104'})]
# query: 「主驗人員」可以由「採購人員」擔任嗎？
# docs: [Document(page_content='可以指定導覽員是某科系學生或某高中校友嗎？', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62783.html'})]
# query: 廠商交貨時是否需要通知採購組派員到場點交及驗收？
# docs: [Document(page_content='我是廠商，請問領取標單、開標、採購案?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62755.html'})]
# query: 如何驗收具有履約起迄期限的租賃和維護案等採購案？
# docs: [Document(page_content='驗收', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 驗收紀錄上的各項簽章欄位應由哪些人擔任？
# docs: [Document(page_content='校務會議提案單各欄位是否都要填寫？', metadata={'url': 'https://sec.ntu.edu.tw/news_content_n_1413_sms_10351_s_4343.html'})]
# query: 驗收紀錄中的「完成履約日期」是如何確定的？
# docs: [Document(page_content='行政會議紀錄經下次會議(2週後)確認後，於隔日將簽案公文交換送回原提案單位。', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1412_sms_10350_s_4338.html'})]
# query: 廠商逾期交貨要如何處理違約金的繳交方式？
# docs: [Document(page_content='錯收公文時怎麼辦？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1431_sms_10369_s_4430.html'})]
# query: 契約變更的流程是什麼？
# docs: [Document(page_content='流程如下，詳見附件流程簡圖：', metadata={'url': 'https://www.nd.ntu.edu.tw/News_Content.aspx?n=70&s=661'})]
# query: 如何辦理驗收（預算金額NTD300,000元以上）？
# docs: [Document(page_content='驗收', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 如何辦理驗收之採購案後續報帳文件及流程？
# docs: [Document(page_content='結案報帳', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 驗收通常在什麼時候辦理？
# docs: [Document(page_content='驗收', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 當交貨點收後進行功能檢測時，如果發現不符合契約規格或有瑕疵，應該如何處理？
# docs: [Document(page_content='140.112.4.231的憑證，會有安全性警告，請按是繼續處理', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 何謂「契約終止」、「契約解除」及「暫停執行」？
# docs: [Document(page_content='產品上市期限 學校從事技術移轉的目的，主要是希望研發成果能獲得實現或商品化，為避免廠商技轉之目的為阻止其他競爭對手使用，或是不積極進行商品化，因此合約內定有產品上市期限之約定。', metadata={'url': 'https://ord.ntu.edu.tw/w/ordntu/Alumnus_20072014431973523?bookmark=21080211363032413'})]
# query: 共約是否已經考慮到大量訂購的優惠條款？
# docs: [Document(page_content='共約', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 共同供應契約應注意事項有哪些？
# docs: [Document(page_content='常見問題-共約', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=78&uid=104&pid=104'})]
# query: 何種情況下需要採購組的協助辦理借款案件？
# docs: [Document(page_content='我是廠商，請問領取標單、開標、採購案?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62755.html'})]
# query: 如何製作借款申請書？
# docs: [Document(page_content='申請表格', metadata={'url': 'https://web.ee.ntu.edu.tw/qa3.php'})]
# query: 借款申請書需要製作幾份？應該附上哪些文件？
# docs: [Document(page_content='提案如果有附件，需要印幾份給代表？', metadata={'url': 'https://sec.ntu.edu.tw/news_content_n_1413_sms_10351_s_4344.html'})]
# query: 請問借款申請人需要哪些人核章？
# docs: [Document(page_content='申請方式與檢附下列資料：', metadata={'url': 'http://www.oc.ntu.edu.tw/?page_id=15221'})]
# query: 借款匯率是根據什麼來決定的？
# docs: [Document(page_content='由誰決定?', metadata={'url': 'https://ord.ntu.edu.tw/w/ordntu/Alumnus_20072014431973523?bookmark=21080211363184051'})]
# query: 如何處理借款結餘款？
# docs: [Document(page_content='結案報帳', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 借款申請需要多久的時間？流程是怎樣的？
# docs: [Document(page_content='申請期限：', metadata={'url': 'http://www.oc.ntu.edu.tw/?page_id=15221'})]
# query: 外購案借款時，兆豐銀行的受款人代碼及統一編號是什麼？
# docs: [Document(page_content='結案報帳', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 保固保證金的收、退應注意事項是什麼？
# docs: [Document(page_content='保證金', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 履約保證金的收、退應注意事項有哪些？
# docs: [Document(page_content='保證金', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 內購案結案報帳應檢附文件及注意事項為何？
# docs: [Document(page_content='結案報帳', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 外購案結案報帳應檢附文件及注意事項為何？
# docs: [Document(page_content='結案報帳', metadata={'url': 'https://ga.ntu.edu.tw/procurement/main_ch/faqList.aspx?faq=75&uid=104&pid=104'})]
# query: 如何查詢拒絶往來廠商說明？
# docs: [Document(page_content='可填寫廠商合作/技轉意願表', metadata={'url': 'https://ord.ntu.edu.tw/w/ordntu/Alumnus_20072014431973523?bookmark=21080211362884042'})]
# query: 採購案件案號編碼規範和各單位案號代碼表的發佈日期是什麼時候？
# docs: [Document(page_content='我是廠商，請問領取標單、開標、採購案?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62755.html'})]
# query: 報紙訂閱異動申請書在哪裡可以找到？
# docs: [Document(page_content='請洽展書樓保管組動產股，相關位置請參考保管組網頁。', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62760.html'})]
# query: 如何申請大型飲水機？
# docs: [Document(page_content='歡迎多加利用自動申請機（共有兩台）；分別位於註冊組兩側，面對註冊組的右側為申請大學部相關證明專用，左側為申請研究所相關證明專用。', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62438.html'})]
# query: 採購契約外之配備金額逾新臺幣15萬元，但未達新臺幣150萬元之採購程序是什麼？前述增購部分機關是否需要與廠商另訂契約？
# docs: [Document(page_content='我是廠商，請問領取標單、開標、採購案?', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55961_sms_15514_s_62755.html'})]
# query: 校內同仁代墊貨款時應該注意什麼事項？
# docs: [Document(page_content='三、學生兼任助理需要加保嗎？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 契約製作時應注意的文件有哪些？
# docs: [Document(page_content='除簽案外，還需要準備什麼資料嗎？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1412_sms_10350_s_4336.html'})]
# query: 契約變更的範圍及態樣有哪些？有哪些注意事項？
# docs: [Document(page_content='線上申請變更及註銷案即可。', metadata={'url': 'https://sec.ntu.edu.tw/news_content_n_1421_sms_10359_s_4391.html'})]
# query: 政府電子採購網帳號申請/IC卡申請/帳號異動等事項
# docs: [Document(page_content='本網頁僅供參考，若有任何最新異動，仍以行政公告所公布之最新異動資料為準。', metadata={'url': 'https://www.nd.ntu.edu.tw/News_Content.aspx?n=70&s=662'})]
# query: 辦理技術移轉程序需要填寫哪些表格？
# docs: [Document(page_content='辦理技術移轉程序為何?', metadata={'url': 'https://ord.ntu.edu.tw/w/ordntu/Alumnus_20072014431973523?bookmark=21080211363184051'})]
# query: 產學合作與技術移轉的時機分別是什麼？
# docs: [Document(page_content='什麼時候進行產學合作?', metadata={'url': 'https://ord.ntu.edu.tw/w/ordntu/Alumnus_20072014431973523?bookmark=21080211363184051'})]
# query: 何時可以向產學合作總中心提出技轉申請？
# docs: [Document(page_content='何時提出技轉申請?', metadata={'url': 'https://ord.ntu.edu.tw/w/ordntu/Alumnus_20072014431973523?bookmark=21080211363184051'})]
# query: 技術移轉案的授權條件是否固定？原則為何？由誰來決定？
# docs: [Document(page_content='技術移轉案的授權條件是固定的嗎?', metadata={'url': 'https://ord.ntu.edu.tw/w/ordntu/Alumnus_20072014431973523?bookmark=21080211363184051'})]
# query: 如何與台大合作？
# docs: [Document(page_content='如何與台大合作?', metadata={'url': 'https://ord.ntu.edu.tw/w/ordntu/Alumnus_20072014431973523?bookmark=21080211363184051'})]
# query: 為何需要在計畫開始時繳交先期技轉金？
# docs: [Document(page_content='為何繳交先期技轉金?', metadata={'url': 'https://ord.ntu.edu.tw/w/ordntu/Alumnus_20072014431973523?bookmark=20082602041819571'})]
# query: 若成功選上國際生接待志工，是否只能抵免服務學習二？
# docs: [Document(page_content='若成功選上國際生接待志工，只能抵免服務學習二嗎？', metadata={'url': 'https://oia.ntu.edu.tw/faq'})]
# query: 計中系統的啟用時間是什麼時候？
# docs: [Document(page_content='計中系統何時可以啟用？', metadata={'url': 'https://oia.ntu.edu.tw/faq'})]
# query: 3. 國際學生計中系統的帳號與密碼是什麼？
# docs: [Document(page_content='國際學生計中系統的帳號與密碼？', metadata={'url': 'https://oia.ntu.edu.tw/faq'})]
# query: 4. 如何查詢國際學生的學號？
# docs: [Document(page_content='哪裡可以知道國際學生的學號？', metadata={'url': 'https://oia.ntu.edu.tw/faq'})]
# query: 國際學生是否可以提前入住臺大宿舍？
# docs: [Document(page_content='國際學生想要提早入住可以嗎？', metadata={'url': 'https://oia.ntu.edu.tw/faq'})]
# query: 6. 國際學生是否有選課限制？
# docs: [Document(page_content='國際學生的選課?', metadata={'url': 'https://oia.ntu.edu.tw/faq'})]
# query: 7. 華語學習的報名方式是什麼？
# docs: [Document(page_content='A. 怎麼報名華語課 國際學生在「線上申請系統 Online Application System」填寫調查時，必須勾選要學習華語課，並且參加之後「華語課程報到與分班測驗」', metadata={'url': 'https://oia.ntu.edu.tw/faq'})]
# query: 外文系選課常見問答集的最新更新日期是什麼時候？
# docs: [Document(page_content='外文系選課常見問答集(109.08.10更新)', metadata={'url': 'https://www.forex.ntu.edu.tw/%e5%a4%96%e6%96%87%e7%b3%bb%e9%81%b8%e8%aa%b2%e5%b8%b8%e8%a6%8b%e5%95%8f%e7%ad%94%e9%9b%86109-08-10%e6%9b%b4%e6%96%b0/'})]
# query: Q 1: What is the screening process for the program selection?
# docs: [Document(page_content='Step 3: Check the course selection result', metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# query: Q 2：申請表上所列「其他相關之有利申請資料」可以提供哪些文件作為證明？
# docs: [Document(page_content='其他相關之有利申請資料雖不是必備文件，但會列入資料審查之參考', metadata={'url': 'https://www.forex.ntu.edu.tw/%e5%b8%b8%e8%a6%8b%e5%95%8f%e9%a1%8c-%e7%bf%bb%e8%ad%af%e5%ad%b8%e7%a8%8b/'})]
# query: 如果我對筆譯和口譯都有興趣，是否可以同時申請並修習兩個組別的專業選修課程？
# docs: [Document(page_content='筆譯組必選三門筆譯專業選修，口譯組必選逐步口譯一、二外加一門口譯專業選修', metadata={'url': 'https://www.forex.ntu.edu.tw/%e5%b8%b8%e8%a6%8b%e5%95%8f%e9%a1%8c-%e7%bf%bb%e8%ad%af%e5%ad%b8%e7%a8%8b/'})]
# query: Q 4：修習口筆譯組是否有特定的學分要求？
# docs: [Document(page_content='口筆譯組皆須修習7學分的共同必修，與12學分的專業選修', metadata={'url': 'https://www.forex.ntu.edu.tw/%e5%b8%b8%e8%a6%8b%e5%95%8f%e9%a1%8c-%e7%bf%bb%e8%ad%af%e5%ad%b8%e7%a8%8b/'})]
# query: Q 5：如果外文系學生已經修習了必修的翻譯及習作，是否還需要修習翻譯實作？
# docs: [Document(page_content='外文系學生畢業時，提交學生報告書可將翻譯實作替代為翻譯及習作', metadata={'url': 'https://www.forex.ntu.edu.tw/%e5%b8%b8%e8%a6%8b%e5%95%8f%e9%a1%8c-%e7%bf%bb%e8%ad%af%e5%ad%b8%e7%a8%8b/'})]
# query: Q 6：學程學分是否可以算入畢業學分？
# docs: [Document(page_content='可計入學程學分', metadata={'url': 'https://www.forex.ntu.edu.tw/%e5%b8%b8%e8%a6%8b%e5%95%8f%e9%a1%8c-%e7%bf%bb%e8%ad%af%e5%ad%b8%e7%a8%8b/'})]
# query: Q 7：如果只修完一個學期的全學年課程，是否可以計入學程學分？
# docs: [Document(page_content='可計入學程學分', metadata={'url': 'https://www.forex.ntu.edu.tw/%e5%b8%b8%e8%a6%8b%e5%95%8f%e9%a1%8c-%e7%bf%bb%e8%ad%af%e5%ad%b8%e7%a8%8b/'})]
# query: Q 8：非學程學生是否可以修習學程課程？
# docs: [Document(page_content='可計入學程學分', metadata={'url': 'https://www.forex.ntu.edu.tw/%e5%b8%b8%e8%a6%8b%e5%95%8f%e9%a1%8c-%e7%bf%bb%e8%ad%af%e5%ad%b8%e7%a8%8b/'})]
# query: Q 9：是否有特殊原因可以申請學程課程的暑期班？
# docs: [Document(page_content='基本上本學程不主動開設暑期班，但同學若有特殊原因，請與授課老師協調後，依教務處規定填寫學生暑修申請書提出申請', metadata={'url': 'https://www.forex.ntu.edu.tw/%e5%b8%b8%e8%a6%8b%e5%95%8f%e9%a1%8c-%e7%bf%bb%e8%ad%af%e5%ad%b8%e7%a8%8b/'})]
# query: 行政會議召開的頻率是多久一次？開會的時間是什麼時候？
# docs: [Document(page_content='行政會議多久召開一次？時間為何？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1412_s_4334.html'})]
# query: 如何提案擬提送行政會議討論（報告）？提案截止時間是什麼時候？
# docs: [Document(page_content='有提案擬提送行政會議討論（報告），應如何提案？提案截止時間是何時？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1412_sms_10350_s_4335.html'})]
# query: 行政會議除了簽案外，還需要準備哪些資料？
# docs: [Document(page_content='除簽案外，還需要準備什麼資料嗎？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1412_sms_10350_s_4336.html'})]
# query: 行政會議紀錄會在哪裡公告？
# docs: [Document(page_content='會議紀錄會上網公告嗎？可在何處查詢到行政會議紀錄？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1412_sms_10350_s_4337.html'})]
# query: 行政會議紀錄經過多久時間後會將簽案公文送回原提案單位？
# docs: [Document(page_content='行政會議紀錄經下次會議(2週後)確認後，於隔日將簽案公文交換送回原提案單位。', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1412_sms_10350_s_4338.html'})]
# query: 請問我可以在哪裡找到校務會議的開會時間？
# docs: [Document(page_content='校務會議的開會時間', metadata={'url': 'https://sec.ntu.edu.tw/QA_02-01.html'})]
# query: 校務會議代表名單可以在哪裡查詢？
# docs: [Document(page_content='校務會議名單、歷年選任代表名單等可在秘書室網頁查詢', metadata={'url': 'https://sec.ntu.edu.tw/news_content_n_1413_sms_10351_s_4340.html'})]
# query: 我有一個案子要提校務會議討論，有什麼程序嗎？
# docs: [Document(page_content='我有案子要提校務會議討論，有什麼程序嗎？', metadata={'url': 'https://sec.ntu.edu.tw/news_content_n_1413_sms_10351_s_4341.html'})]
# query: 秘書室網頁/校務會議專區提供哪些下載資源？
# docs: [Document(page_content='請至秘書室網頁/校務會議專區下載。', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1413_sms_10351_s_4342.html'})]
# query: 校務會議提案單的哪些欄位不需要填寫？
# docs: [Document(page_content='校務會議提案單各欄位是否都要填寫？', metadata={'url': 'https://sec.ntu.edu.tw/news_content_n_1413_sms_10351_s_4343.html'})]
# query: 提案如果有附件，需要印幾份給程序委員會委員？
# docs: [Document(page_content='提案如果有附件，需要印幾份給代表？', metadata={'url': 'https://sec.ntu.edu.tw/news_content_n_1413_sms_10351_s_4344.html'})]
# query: 行政單位的工作報告需在何時之前送秘書室彙整？
# docs: [Document(page_content='行政單位的工作報告需何時送秘書室彙整？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1413_sms_10351_s_4345.html'})]
# query: 校務會議通常會開到幾點？如果當天有其他行程或有要事不能出席，應該怎麼辦？
# docs: [Document(page_content='請問校務會議會開到幾點？如果當天還有其他行程，或另有要事不能出席怎麼辦？', metadata={'url': 'https://sec.ntu.edu.tw/news_content_n_1413_sms_10351_s_4346.html'})]
# query: 校務會議紀錄可以在哪裡查到？
# docs: [Document(page_content='校務會議紀錄哪裡可以查到？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1413_sms_10351_s_4347.html'})]
# query: 如何查詢校務會議議案的執行進度？
# docs: [Document(page_content='校務會議決議事項，如何知道後續執行進度？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1413_sms_10351_s_4348.html'})]
# query: 程序委員會委員的任期是否有限制？
# docs: [Document(page_content='委員的任期多久？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1414_s_4349.html'})]
# query: 程序委員會的開會時間通常是在校務會議前三週嗎？
# docs: [Document(page_content='程序委員會的開會時間是配合校務會議時程，通常約是校務會議前三週。', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1414_s_4350.html'})]
# query: 程序委員會的討論事項是什麼？
# docs: [Document(page_content='程序委員會的討論事項就是排定當次校務會議議案次序及會議程序表。', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1414_sms_10352_s_4351.html'})]
# query: 校務發展規劃委員會每學年至少開幾次會議？
# docs: [Document(page_content='校務發展規劃委員會多久召開1次？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1415_s_4352.html'})]
# query: 如何提案給校務發展規劃委員會？
# docs: [Document(page_content='校務發展規劃委員會', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1415_sms_10353_s_4354.html'})]
# query: 列席校發會說明時，需要注意什麼事項？
# docs: [Document(page_content='列席校發會說明時需注意什麼？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1415_sms_10353_s_4354.html'})]
# query: 我可以在哪裡找到校發會紀錄？
# docs: [Document(page_content='我想查詢某次校發會紀錄？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1415_sms_10353_s_4355.html'})]
# query: 校發會的組成成員有哪些？
# docs: [Document(page_content='校發會如何組成？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1415_s_4356.html'})]
# query: 校發會推選委員的任期是多久？
# docs: [Document(page_content='校發會推選委員任期多久？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1415_sms_10353_s_4357.html'})]
# query: 行政品質評鑑委員會每隔多久決定一次受評單位？
# docs: [Document(page_content='(1)有關評鑑結果建議改進事項，如已獲受評單位之重視，作為內部業務考量，或交由相關委員會討論追蹤，並回覆說明相關改進作法，確已達成行政品質評鑑之目的，則由本會列為結案。', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1417_sms_10355_s_4367.html'})]
# query: 是否可以由各單位根據其特性自行設計「顧客滿意度問卷調查表」？
# docs: [Document(page_content='顧客滿意度問卷調查表是否可由各單位依其特性自行設計', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1417_sms_10355_s_4363.html'})]
# query: 行政品質評鑑表可以在哪裡下載？
# docs: [Document(page_content='「行政品質評鑑表」可於下列網址下載：http://doc.ntu.edu.tw/tables/秘書室/國立臺灣大學行政品質評鑑表.doc', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1417_sms_10355_s_4364.html'})]
# query: 行政品質評鑑時，訪評當日應注意哪些事項？
# docs: [Document(page_content='訪評當日應注意事項？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1417_sms_10355_s_4365.html'})]
# query: 「建議改進事項執行情形報告表」應該多久填報一次？
# docs: [Document(page_content='建議改進事項執行情形報告表應多久填報1次', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1417_sms_10355_s_4366.html'})]
# query: 「行政品質評鑑中的建議改進事項何時可以結束追蹤，不需要再填報？」
# docs: [Document(page_content='建議改進事項追蹤案何時可結束追蹤，免再填報？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1417_sms_10355_s_4367.html'})]
# query: 教師在什麼情況下可以提出申訴？
# docs: [Document(page_content='教師對學校或主管機關有關其個人之措施，認為違法或不當，致損害其權益者，得提出申訴。', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1418_s_4368.html'})]
# query: 如何向教師申訴？
# docs: [Document(page_content='教師對學校或主管機關有關其個人之措施，認為違法或不當，致損害其權益者，得提出申訴。', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1418_s_4368.html'})]
# query: 如何申訴教師？
# docs: [Document(page_content='教師對學校或主管機關有關其個人之措施，認為違法或不當，致損害其權益者，得提出申訴。', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1418_s_4368.html'})]
# query: 教師申訴的書面送出期限是多久？
# docs: [Document(page_content='申訴資料應於何時送出？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1419_sms_10357_s_4379.html'})]
# query: 申訴人在申訴提出後，需要做哪些後續工作？
# docs: [Document(page_content='申訴提出後，申訴人尚需做哪些後續工作？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1418_sms_10356_s_4372.html'})]
# query: 教師申訴結果不滿意時，應該在多久內向教育部中央教師申訴評議委員會提起再申訴？
# docs: [Document(page_content='應於申訴評議書送達之次日起30日內以書面向教育部中央教師申訴評議委員會提起再申訴。依「教師申訴評議委員會組織及評議準則」第9條及「國立臺灣大學教師申訴評議委員會組織及運作辦法」第24條規定辦理。', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1418_sms_10356_s_4374.html'})]
# query: 在哪些情況下，不會受理教師的申訴？
# docs: [Document(page_content='在什麼情況下，不受理申訴？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1418_sms_10356_s_4375.html'})]
# query: 何種情況下可以提出職員申訴？
# docs: [Document(page_content='何種情況下可提申訴？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1418_s_4368.html'})]
# query: 如何向秘書室提出職員申訴？
# docs: [Document(page_content='申訴表格可於秘書室「業務相關表格」下載', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1419_sms_10357_s_4378.html'})]
# query: 如何提出申訴？
# docs: [Document(page_content='如何提出申訴？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1418_sms_10356_s_4370.html'})]
# query: 職員申訴的截止日期是多久？
# docs: [Document(page_content='申訴資料應於何時送出？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1419_sms_10357_s_4379.html'})]
# query: 申訴人在申訴提出後，需要做哪些後續工作？
# docs: [Document(page_content='申訴提出後，申訴人尚需做哪些後續工作？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1418_sms_10356_s_4372.html'})]
# query: 當對申訴結果仍不滿意時，應該向哪個機構提起再申訴？
# docs: [Document(page_content='對申訴結果仍不滿意時，應該怎麼辦？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1419_sms_10357_s_4381.html'})]
# query: 在什麼情況下，不會受理職員的申訴？
# docs: [Document(page_content='在什麼情況下，不受理申訴？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1418_sms_10356_s_4375.html'})]
# query: 當需要修改秘書室法規彙編內的各單位法規時，應該如何處理？
# docs: [Document(page_content='秘書室法規彙編內之各單位法規需異動時如何處理？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1420_s_4383.html'})]
# query: 如何在秘書室法規彙編網頁上快速搜尋需要的法規？
# docs: [Document(page_content='如何快速找到需要的法規？', metadata={'url': 'https://sec.ntu.edu.tw/News_Content_n_1420_sms_10358_s_4384.html'})]
# query: 申請科技部「補助國內專學者出席國際會議」申請案需要提出多久時間？
# docs: [Document(page_content='申請科技部「補助國內專學者出席國際會議」申請案提出時間？', metadata={'url': 'https://sec.ntu.edu.tw/p7-faq-detail-MOST01.html'})]
# query: 科技部撥付補助舉辦研討會之補助款是否可以直接撥付給廠商？
# ...
# query: 請問大學部電機工程學系的學生可以申請哪些獎學金？
# docs: [Document(page_content='大學部獎學金', metadata={'url': 'https://web.ee.ntu.edu.tw/qa3.php'})]
# query: 如何聯絡電機工程學系的系學會？
# docs: [Document(page_content='由於科系座談的需求各異，為達到最有效率的溝通，建議您直接聯絡各系所。', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62782.html'})]
# query: 請問電機系館舍的門禁系統需要找誰處理？
# docs: [Document(page_content='電機系館舍打掃，含電二館、博理館、明達館等，由服務甲助教統籌安排', metadata={'url': 'https://web.ee.ntu.edu.tw/qa3.php'})]
# query: 請問電機系館舍的門禁系統設定，應該找哪個單位處理？
# docs: [Document(page_content='電機系館舍打掃，含電二館、博理館、明達館等，由服務甲助教統籌安排', metadata={'url': 'https://web.ee.ntu.edu.tw/qa3.php'})]
# query: 請問在哪裡可以找到電機系的網管陳先生？
# docs: [Document(page_content='電機系網管', metadata={'url': 'https://web.ee.ntu.edu.tw/qa3.php'})]
# query: VPN啟用後需要多久才能成功登入計算機中心？
# docs: [Document(page_content='由此線上啟用VPN權限 已經登入並連上VPN，但之後無法連上網頁，會反覆重新連線？', metadata={'url': 'https://ccnet.ntu.edu.tw/vpn/faq.html?fbclid=IwAR0ymKoVH-SHCYwiHKC_tq0yhKBgG-Sti82SDDEDB4JFnaJkLKGdjnBeFgE#faq1-1'})]
# query: 我已經登入並連上VPN，但之後無法連上網頁，會反覆重新連線？
# docs: [Document(page_content='由此線上啟用VPN權限 已經登入並連上VPN，但之後無法連上網頁，會反覆重新連線？', metadata={'url': 'https://ccnet.ntu.edu.tw/vpn/faq.html?fbclid=IwAR0ymKoVH-SHCYwiHKC_tq0yhKBgG-Sti82SDDEDB4JFnaJkLKGdjnBeFgE#faq1-1'})]
# query: 我在連VPN時，出現 "未能連線至「pulse secure 統一網路服務」" 的錯誤訊息，該怎麼辦？
# docs: [Document(page_content='卡巴斯基 MacOS電腦在連VPN時，出現未能連線至「pulse secure 統一網路服務」的錯誤訊息', metadata={'url': 'https://ccnet.ntu.edu.tw/vpn/faq.html?fbclid=IwAR0ymKoVH-SHCYwiHKC_tq0yhKBgG-Sti82SDDEDB4JFnaJkLKGdjnBeFgE#faq1-1'})]
# query: VPN一直停在「正在保護連線安全」狀態，或出現「未能設定虛擬配接卡」錯誤訊息，應該如何處理？
# docs: [Document(page_content='VPN一直停在正在保護連線安全狀態', metadata={'url': 'https://ccnet.ntu.edu.tw/vpn/faq.html?fbclid=IwAR0ymKoVH-SHCYwiHKC_tq0yhKBgG-Sti82SDDEDB4JFnaJkLKGdjnBeFgE#faq1-1'})]
# query: 在MacOS 15.6版本電腦上開啟下載的「Pulse Secure」時，出現「無法打開 App，因為 Apple 無法檢查是否包含惡意軟體」的問題，如何解決？
# docs: [Document(page_content='出現無法打開App，因為Apple無法檢查是否包含惡意軟體的問題', metadata={'url': 'https://ccnet.ntu.edu.tw/vpn/faq.html?fbclid=IwAR0ymKoVH-SHCYwiHKC_tq0yhKBgG-Sti82SDDEDB4JFnaJkLKGdjnBeFgE#faq1-1'})]
# query: 我無法連線到計算機中心，即使我已經移除舊版的Pulse Secure並重新安裝了新版。我應該如何手動清除殘餘檔案並重新安裝呢？
# docs: [Document(page_content='電腦上安裝了不同版本的Pulse Secure程式', metadata={'url': 'https://ccnet.ntu.edu.tw/vpn/faq.html?fbclid=IwAR0ymKoVH-SHCYwiHKC_tq0yhKBgG-Sti82SDDEDB4JFnaJkLKGdjnBeFgE#faq1-1'})]
# query: 我無法透過VPN連線下載圖書館電子期刊或計中版權軟體，該怎麼辦？
# docs: [Document(page_content='VPN連線後仍無法下載圖書館電子期刊或計中版權軟體', metadata={'url': 'https://ccnet.ntu.edu.tw/vpn/faq.html?fbclid=IwAR0ymKoVH-SHCYwiHKC_tq0yhKBgG-Sti82SDDEDB4JFnaJkLKGdjnBeFgE#faq1-1'})]
# query: 我在登入計算機中心時遇到了「用戶名稱或密碼無效」、「驗證資料無效」、「驗證遭伺服器拒絕」、「無效的使用者名稱或密碼」等錯誤訊息，該怎麼辦？
# docs: [Document(page_content='用戶名稱或密碼無效', metadata={'url': 'https://ccnet.ntu.edu.tw/vpn/faq.html?fbclid=IwAR0ymKoVH-SHCYwiHKC_tq0yhKBgG-Sti82SDDEDB4JFnaJkLKGdjnBeFgE#faq1-1'})]
# query: 為什麼我使用計算機中心的時候會在幾分鐘內斷線？
# docs: [Document(page_content='問題1：為何我用沒幾分鐘就會斷線？', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 安裝 Firefox 或 Chrome 後，導致 IE 無法認證(會一直導回認證畫面)的原因是什麼？
# docs: [Document(page_content='問題2：安裝 Firefox 或 Chrome 後，導致 IE 無法認證(會一直導回認證畫面)？', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 計算機中心問題3：是否需要設定代理伺服器？
# docs: [Document(page_content='問題3：是否需要設定 proxy？', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 無線網路卡 client 端軟體是否只能輸入數組數字而無法提供輸入 WEP key 文字？
# docs: [Document(page_content='問題4：無線網路卡 client 端軟體無法提供輸入 WEP key 文字，而只能輸入數組數字？', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 臺大校內的無線網路建置在哪些地方？
# docs: [Document(page_content='問題5：臺大校內哪些地方有建置無線網路？', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 臺大圖書館內的無線網路服務範圍是否僅限於各樓層部分的公共區域？
# docs: [Document(page_content='問題6：臺大圖書館內是否有提供無線網路的服務？', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 無線網路卡是否可以自行購買並在校內網路中使用？
# docs: [Document(page_content='問題7：關於無線網路卡是否可自行購買，再使用校內網路？', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 問題8：為什麼驅動程式安裝完成後，無線網路卡的燈不斷閃爍，並且無法上網？
# docs: [Document(page_content='問題8：驅動程式安裝完成後，無線網路卡的燈不斷閃爍，而且無法上網，這是什麼原因？', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 網路卡的2個燈號都沒有反應，可能的原因是什麼？
# docs: [Document(page_content='問題9：若網路卡的2個燈號都沒有反應，這是什麼原因？', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 無線網路採用哪些技術來避免資料被竊取？
# docs: [Document(page_content='回答10.1：無線網路採用下列技術避免資料被竊取：', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 兩個點之間的信號是否可以繞過障礙物？
# docs: [Document(page_content='兩個點之間信號繞過障礙的能力', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 於室內使用時，隔板、木板或磚牆對傳輸距離有何影響？
# docs: [Document(page_content='於室內使用時，隔板、木板或磚牆，可能影響多少的傳輸距離', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 無線區域網路的資料傳輸速率有哪些選項？
# docs: [Document(page_content='無線區域網路的資料傳輸速率為何', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 傳輸速率是否會受到距離的影響而改變？
# docs: [Document(page_content='傳輸速率是否會因距離的因素而改變', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 無線網路的有效傳輸距離受到哪些因素的影響？
# docs: [Document(page_content='無線網路的有效傳輸距離約多遠', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 資料傳送的可靠性取決於什麼因素？
# docs: [Document(page_content='資料傳送的可靠性為何', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 無線網路漫遊時，如何提升收訊品質？
# docs: [Document(page_content='無線網路漫遊時，如何得知及改善收訊品質', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 計算機中心是否需要申請無線網路認證的帳號密碼？
# docs: [Document(page_content='是否需要申請無線網路認證的帳號密碼', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 計算機中心的憑證安全性警告是什麼？
# docs: [Document(page_content='有關憑證安全性警告', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 台大ADSL的服務地區包括哪些地區？
# docs: [Document(page_content='問題5：臺大校內哪些地方有建置無線網路？', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 台大ADSL的特色是什麼？
# docs: [Document(page_content='問題5：臺大校內哪些地方有建置無線網路？', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 請問台大ADSL有哪些使用上的限制？
# docs: [Document(page_content='問題5：臺大校內哪些地方有建置無線網路？', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 申請台大ADSL時，有哪些注意事項？
# docs: [Document(page_content='A. 國際學位生、校級交換訪問生在申請臺大入學的時候，有線上申請系統，國際學生都透過該系統進行調查填寫或活動宿舍申請等，因此請提醒國際學生到線上申請系統 Online Application System 查詢', metadata={'url': 'https://oia.ntu.edu.tw/faq'})]
# query: 台大ADSL提供哪些傳輸速率？
# docs: [Document(page_content='無線區域網路的資料傳輸速率為何', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 請問台大ADSL費用如何計算？
# docs: [Document(page_content='問題5：臺大校內哪些地方有建置無線網路？', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 為什麼中華電信的服務人員說變更ISP不需要支付接線費差額？
# docs: [Document(page_content='如果你是國內旅客，可以試試iTaiwan「中央行政機關室內公共區域提供免費無線上網」帳號，詳細說明可參考網頁 https://itaiwan.gov.tw/faq_use.php', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62793.html'})]
# query: 如何申請台大ADSL？
# docs: [Document(page_content='臺大無線網路認證共有2個憑證，其一為 wireless.ntu.edu.tw 該 domain name', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 申請計算機中心之後，需要多久才能進行施工呢？
# docs: [Document(page_content='計中系統何時可以啟用？', metadata={'url': 'https://oia.ntu.edu.tw/faq'})]
# query: 我該如何處理中華電信裝機人員臨時打來的電話要施工的情況？
# docs: [Document(page_content='十四、部分工時人員與臨時人員有什麼不同？', metadata={'url': 'http://www.personnel.ntu.edu.tw/cp_n_2778.html'})]
# query: 我如何查詢我的IP地址？
# docs: [Document(page_content='透過我的IP位址查詢可顯示您的連線IP位址', metadata={'url': 'https://ccnet.ntu.edu.tw/vpn/faq.html?fbclid=IwAR0ymKoVH-SHCYwiHKC_tq0yhKBgG-Sti82SDDEDB4JFnaJkLKGdjnBeFgE#faq1-1'})]
# query: 我的電腦需要做哪些設定？
# docs: [Document(page_content='在系統偏好設定中', metadata={'url': 'https://ccnet.ntu.edu.tw/vpn/faq.html?fbclid=IwAR0ymKoVH-SHCYwiHKC_tq0yhKBgG-Sti82SDDEDB4JFnaJkLKGdjnBeFgE#faq1-1'})]
# query: 如何檢查我的電腦設定是否正確？
# docs: [Document(page_content='請透過以下方式確認是否以VPN IP連線', metadata={'url': 'https://ccnet.ntu.edu.tw/vpn/faq.html?fbclid=IwAR0ymKoVH-SHCYwiHKC_tq0yhKBgG-Sti82SDDEDB4JFnaJkLKGdjnBeFgE#faq1-1'})]
# query: 我無法上網，該怎麼解決？
# docs: [Document(page_content='問題8：驅動程式安裝完成後，無線網路卡的燈不斷閃爍，而且無法上網，這是什麼原因？', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 我加入台大ADSL後，為什麼我的Outlook Express出現問題？
# docs: [Document(page_content='表示並未成功連上臺大VPN', metadata={'url': 'https://ccnet.ntu.edu.tw/vpn/faq.html?fbclid=IwAR0ymKoVH-SHCYwiHKC_tq0yhKBgG-Sti82SDDEDB4JFnaJkLKGdjnBeFgE#faq1-1'})]
# query: 我上網的速度好慢，幾乎沒辦法連線。
# docs: [Document(page_content='由此線上啟用VPN權限 已經登入並連上VPN，但之後無法連上網頁，會反覆重新連線？', metadata={'url': 'https://ccnet.ntu.edu.tw/vpn/faq.html?fbclid=IwAR0ymKoVH-SHCYwiHKC_tq0yhKBgG-Sti82SDDEDB4JFnaJkLKGdjnBeFgE#faq1-1'})]
# query: 我的電腦可能中了疾風病毒，應該怎麼處理？
# docs: [Document(page_content='解決方法為', metadata={'url': 'https://ccnet.ntu.edu.tw/vpn/faq.html?fbclid=IwAR0ymKoVH-SHCYwiHKC_tq0yhKBgG-Sti82SDDEDB4JFnaJkLKGdjnBeFgE#faq1-1'})]
# query: 我家中有多台電腦要上網，請問要購買何種設備？
# docs: [Document(page_content='問題7：關於無線網路卡是否可自行購買，再使用校內網路？', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 我在家中想要無線上網，應該怎麼做呢？
# docs: [Document(page_content='回答10.1：無線網路採用下列技術避免資料被竊取：', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 我想要變更速率，應該如何處理？
# docs: [Document(page_content='傳輸速率是否會因距離的因素而改變', metadata={'url': 'https://ccnet.ntu.edu.tw/wireless/ccnet/wireless.php?page=faq&fbclid=IwAR3IGBJKqCu6QG4DkKC4c3EcGvo8R8YvS_Ovep3wieaPIVhftFmVkXUztps'})]
# query: 我想要辦理變更附掛電話或移機，應該如何辦理呢？
# docs: [Document(page_content='線上申請變更及註銷案即可。', metadata={'url': 'https://sec.ntu.edu.tw/news_content_n_1421_sms_10359_s_4391.html'})]
# query: 如果我延畢或升學，需要重新辦理計算機中心的相關事務嗎？
# docs: [Document(page_content='是否可以到畢業前再來受訓？', metadata={'url': 'https://www.ch.ntu.edu.tw/esh.html'})]
# query: 畢業後多久，我就不能使用計算機中心了？
# docs: [Document(page_content='計中系統何時可以啟用？', metadata={'url': 'https://oia.ntu.edu.tw/faq'})]
# query: 我已經畢業了，但我的家人或室友還在學，我需要重新辦理計算機中心的手續嗎？
# docs: [Document(page_content='是否可以到畢業前再來受訓？', metadata={'url': 'https://www.ch.ntu.edu.tw/esh.html'})]
# query: 我想要改接其他網路業者的ADSL，應該怎麼辦理？
# docs: [Document(page_content='如果你是國內旅客，可以試試iTaiwan「中央行政機關室內公共區域提供免費無線上網」帳號，詳細說明可參考網頁 https://itaiwan.gov.tw/faq_use.php', metadata={'url': 'https://visitorcenter.ntu.edu.tw/News_Content_n_55962_sms_58493_s_62793.html'})]
# query: 如何登入我的NTU電子郵件帳戶？
# docs: [Document(page_content='How do I access my NTU email?', metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# query: 台大學生最重要的網站有哪些？
# docs: [Document(page_content='台大學生最重要的網站是什麼？', metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# query: 如何選課？
# docs: [Document(page_content='如何選課？', metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# query: 我應該去哪裡繳交學費？
# docs: [Document(page_content='我應該去哪裡得到學費繳交訊息？', metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# query: What are some websites where I can find information about off-campus housing options?
# docs: [Document(page_content='off-campus housing', metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# query: 如何準備我的第一堂專題討論（一）課？
# docs: [Document(page_content='How do I prepare for my first Seminar I class?', metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# query: 永續發展國際學位學程的專題討論（二）課程規定是什麼？
# docs: [Document(page_content='碩士生除專討之外的必修課程相關規定', metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# query: 碩士生專討一與專討三的規定是什麼？
# docs: [Document(page_content="碩士生專討三與四的規定 (1) Taking “Seminar III” requires passing “Seminar I”. If student want to'", metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# query: 博士生專討三四五六的相關規定是什麼？
# docs: [Document(page_content='Q: 博士生專討三四五六的相關規定', metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# query: 碩士生除了專討之外的必修課程有哪些？
# docs: [Document(page_content='碩士生除專討之外的必修課程相關規定', metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# query: 氣候變遷與永續發展國際學位學程的博士生除了專討之外的必修課程有哪些相關規定？
# docs: [Document(page_content='博士生除專討之外的必修課程相關規定', metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# query: 學術倫理課程是由誰規定的？
# docs: [Document(page_content='學術倫理課程是教育部規定所有台灣研究生必修的6小時線上課程', metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# query: IPCS學生是否有兼職工作機會？
# docs: [Document(page_content='Are there part-time jobs available for IPCS students?', metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# query: 我在校工作時，是否需要申請工作許可證？
# docs: [Document(page_content='Chinese and foreign students are found online here 留學生必須申請工作許可證，並同時擁有中華郵政局的帳戶才能領取工資。針對中國和外國學生的工作許可申請： https://ezwp.wda.gov.tw/wcfonline/wSite/Control?function=IndexPage', metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# query: IPC課程的選課期限是什麼時候？
# docs: [Document(page_content='When is the Add/Drop period for IPCS courses? Please refer to the NTU Academic Calendar for specific course selection dates. 關於校內選課的時程，請參考NTU行事曆。', metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# query: 核心課程是以講演為主還是實作課程為主？
# docs: [Document(page_content='Are the core courses mostly lectures or laboratory-based? 核心課程主要是講演還是實作課程？', metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# query: 學生應該如何選擇投稿的期刊？
# docs: [Document(page_content="How can IPCS student select journal to submit? 學生該如何選擇投稿的期刊?'", metadata={'url': 'http://www.ipcs.ntu.edu.tw/page/about/index.aspx?kind=2155'})]
# Recall@1, ChatGPT Generated Question Accuracy: 0.5711678832116789
# 0.5711678832116789

# %% [markdown]
# ### BM25 TEST

# %%
# Only BM25
from langchain.retrievers import BM25Retriever

bm25_retriever = BM25Retriever.from_documents(docs)

Ks = [1, 5, 10, 20, 50, 100]
for K in Ks:
    # initialize the bm25 retriever and faiss retriever
    bm25_retriever.k = K
    retriever_original(retriever, K)
    retriever_eval(bm25_retriever, K)
    hyde_retriever_eval(bm25_retriever, K)
# Out:
# Recall@1, Original Question Accuracy: 0.8138686131386861
# Recall@1, ChatGPT Generated Question Accuracy: 0.025547445255474453
# Recall@1, ChatGPT Generated Question with HyDE Accuracy: 0.016423357664233577
# Recall@5, Original Question Accuracy: 0.8138686131386861
# Recall@5, ChatGPT Generated Question Accuracy: 0.032846715328467155
# Recall@5, ChatGPT Generated Question with HyDE Accuracy: 0.023722627737226276
# Recall@10, Original Question Accuracy: 0.8138686131386861
# Recall@10, ChatGPT Generated Question Accuracy: 0.032846715328467155
# Recall@10, ChatGPT Generated Question with HyDE Accuracy: 0.025547445255474453
# Recall@20, Original Question Accuracy: 0.8138686131386861
# Recall@20, ChatGPT Generated Question Accuracy: 0.032846715328467155
# Recall@20, ChatGPT Generated Question with HyDE Accuracy: 0.02737226277372263
# Recall@50, Original Question Accuracy: 0.8138686131386861
# Recall@50, ChatGPT Generated Question Accuracy: 0.032846715328467155
# Recall@50, ChatGPT Generated Question with HyDE Accuracy: 0.029197080291970802
# Recall@100, Original Question Accuracy: 0.8138686131386861
# Recall@100, ChatGPT Generated Question Accuracy: 0.032846715328467155
# Recall@100, ChatGPT Generated Question with HyDE Accuracy: 0.03102189781021898

# %% [markdown]
# ### MultiQ

# %%
import pandas as pd

multiQ_df = pd.read_csv('document/FAQ_ChatGPT_MultiQ.csv')
multiQ_df.head()
# Out:
#                                                 URL  \
# 0  https://admissions.ntu.edu.tw/zh-hant/apply/faq/
# 1  https://admissions.ntu.edu.tw/zh-hant/apply/faq/
# 2  https://admissions.ntu.edu.tw/zh-hant/apply/faq/
# 3  https://admissions.ntu.edu.tw/zh-hant/apply/faq/
# 4  https://admissions.ntu.edu.tw/zh-hant/apply/faq/
#
#                                 Question  \
# 0            學生身份別之間有什麽差異？我應該如何查詢我的身份別呢？
# 1  學生身份別的不同會帶來甚麼差異？如果我同時符合兩個身份別，那應該如何處理？
# 2                  我現在就讀於其他大學，我可以轉學到臺大嗎？
# 3                            臺大的教學語言是什麽？
# 4                            臺大有提供哪些課程呢？
#
#                                               Answer  \
# 0  學生身份別一共分四種：國際生、僑生、港澳生及陸生。您可以透過境外學位生身份別測驗來查詢自己的...
# 1  根據學生身份別的不同，入學流程、學費、獎助學金、開放的系所及一些相關限制都會有差異。建議您在...
# 2  如您為目前正攻讀學士學位的國際生，請參考國際生二年級入學頁面。至於僑、港澳生，如您目前在臺灣...
# 3  臺大主要以中文及英文為授課語言。英語授課系所可分為 1. 部分英語授課，即以英語授課的科目數...
# 4  臺大致力於提供全面的教育，因此課程包括系上必修課程、通識教育課程和人文教育課程。通識教育核心...
#
#                                       ChatGPT_MultiQ
# 0  學生身份別有哪些類別？我該如何確認自己的身份別？\n問：學生身份分為幾種？我要如何查詢自己的...
# 1  學生身份別的不同會對入學流程有什麼影響？\n    問：如果我同時符合兩個身份別，我可以同時...
# 2  我目前在其他大學就讀，可以轉學到臺大嗎？\n    問：我是一名國際生，可以轉學到臺大嗎？\...
# 3  臺大的教學語言有哪些？\n問：臺大的授課語言是什麽？\n問：臺大的主要教學語言是什麽？\n問...
# 4  臺大提供哪些核心通識教育課程？\n    問：臺大的人文教育課程有哪些類別？\n    問：...

# %%
def retriever_multiQ_eval(testset, retriever, k):

    retrieve_urls = []
    
    for idx, query in enumerate(testset['ChatGPT_MultiQ']):
        # print('query:', query)
        docs = retriever.get_relevant_documents(query)
        # print('docs:', docs)
        retrieve_urls.append(sorted([(doc.metadata['url'])for doc in docs]))
    
    correct_cnt = 0
    for idx, d in enumerate(testset.iterrows()):
        if d[1]['URL'] in retrieve_urls[idx]:
            correct_cnt+=1

    print(f'Recall@{k}, *Multi Query* ChatGPT Generated Question Accuracy: {correct_cnt/len(testset)}')
    return correct_cnt/len(testset)

# def hyde_retriever_eval(retriever, k):

#     retrieve_urls = []
    
#     for idx, query in enumerate(testset['ChatGPT_MultiQ']):
#         # print('query:', query)
#         docs = retriever.get_relevant_documents(query+testset['HyDE'][idx])
#         # print('docs:', docs)
#         retrieve_urls.append(sorted([(doc.metadata['url'])for doc in docs]))
    
#     correct_cnt = 0
#     for idx, d in enumerate(testset.iterrows()):
#         if d[1]['URL'] in retrieve_urls[idx]:
#             correct_cnt+=1
    
#     print(f'Recall@{k}, ChatGPT Generated Question with HyDE Accuracy: {correct_cnt/len(testset)}')
#     return correct_cnt/len(testset)

# def retriever_original(retriever, k):

#     retrieve_urls = []
    
#     for idx, query in enumerate(testset['Question']):
#         # print('query:', query)
#         docs = retriever.get_relevant_documents(query)
#         # print('docs:', docs)
#         retrieve_urls.append(sorted([(doc.metadata['url'])for doc in docs]))
    
#     correct_cnt = 0
#     for idx, d in enumerate(testset.iterrows()):
#         if d[1]['URL'] in retrieve_urls[idx]:
#             correct_cnt+=1
#     # print(f"Correct Answer: {d[1]['URL']}")
#     # print(f'Retrieve document urls:')
#     # [print(url) for url in retrieve_urls[idx]]
#     print(f'Recall@{k}, Original Question Accuracy: {correct_cnt/len(testset)}')
#     return correct_cnt/len(testset)

# %%
from langchain.vectorstores import FAISS

db = FAISS.load_local('embeddings/faq_bge_large_chatgpt', embeddings)

Ks = [1, 5, 10, 20, 50, 100]

for K in Ks:
    retriever = db.as_retriever(search_kwargs={"k": K})
    retriever_eval(retriever, K)
    retriever_multiQ_eval(multiQ_df, retriever, K)
    # retriever_original(retriever, K)
# Out:
# Recall@1, ChatGPT Generated Question Accuracy: 0.5711678832116789
# Recall@1, *Multi Query* ChatGPT Generated Question Accuracy: 0.5474452554744526
# Recall@5, ChatGPT Generated Question Accuracy: 0.6733576642335767
# Recall@5, *Multi Query* ChatGPT Generated Question Accuracy: 0.6368613138686131
# Recall@10, ChatGPT Generated Question Accuracy: 0.7098540145985401
# Recall@10, *Multi Query* ChatGPT Generated Question Accuracy: 0.6788321167883211
# Recall@20, ChatGPT Generated Question Accuracy: 0.7299270072992701
# Recall@20, *Multi Query* ChatGPT Generated Question Accuracy: 0.7135036496350365
# Recall@50, ChatGPT Generated Question Accuracy: 0.7755474452554745
# Recall@50, *Multi Query* ChatGPT Generated Question Accuracy: 0.7591240875912408
# Recall@100, ChatGPT Generated Question Accuracy: 0.8102189781021898
# Recall@100, *Multi Query* ChatGPT Generated Question Accuracy: 0.801094890510949
